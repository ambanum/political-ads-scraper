# %%
import json
import re

import fetch

# %% [markdown]
# ## Load ads

# %%
with open('../data/CY/facebook-ads-archive_CY_2019-05-16_20-16-10.json', 'r') as f:
    data_old = json.load(f)
with open('../data/CY/facebook-ads-archive_CY_2019-05-20_11-55-19.json', 'r') as f:
    data_new = json.load(f)

# %%
with open('../data/FR/facebook-ads-archive_FR_2019-05-16_20-37-43.json', 'r') as f:
    data_old = json.load(f)
with open('../data/FR/facebook-ads-archive_FR_2019-05-20_14-03-03.json', 'r') as f:
    data_new = json.load(f)

# %%
len(data_old), len(data_new)
# Out:
# (12934, 13550)

# %%
for field in fetch.FIELDS:
    print('{} ads have the field "{}" on a total of {}'.format(
        sum([field in ad for ad in data_new]),
        field,
        len(data_new)
    ))
# Out:
# 13550 ads have the field "ad_creation_time" on a total of 13550
# 13431 ads have the field "ad_creative_body" on a total of 13550
# 10665 ads have the field "ad_creative_link_caption" on a total of 13550
# 7246 ads have the field "ad_creative_link_description" on a total of 13550
# 11221 ads have the field "ad_creative_link_title" on a total of 13550
# 13550 ads have the field "ad_delivery_start_time" on a total of 13550
# 6875 ads have the field "ad_delivery_stop_time" on a total of 13550
# 13550 ads have the field "ad_snapshot_url" on a total of 13550
# 13550 ads have the field "currency" on a total of 13550
# 13549 ads have the field "demographic_distribution" on a total of 13550
# 925 ads have the field "funding_entity" on a total of 13550
# 13429 ads have the field "impressions" on a total of 13550
# 13550 ads have the field "page_id" on a total of 13550
# 13545 ads have the field "page_name" on a total of 13550
# 13550 ads have the field "region_distribution" on a total of 13550
# 13548 ads have the field "spend" on a total of 13550

# %% [markdown]
# ## Index

# %%
regex = re.compile(r'^https://www\.facebook\.com/ads/archive/render_ad/\?id=(\d+)&access_token=[a-zA-Z0-9]+$')
def get_id(ad):
    return regex.match(ad['ad_snapshot_url']).groups()[0]

def to_dict(ads):
    ads_by_id = {}
    for ad in ads:
        ad_id = get_id(ad)
        assert ad_id not in ads_by_id, ad
        ads_by_id[ad_id] = ad
    return ads_by_id

# %%
data_old_by_id = to_dict(data_old)
data_new_by_id = to_dict(data_new)

# %% [markdown]
# ## Find removed ads

# %%
old_ids = set(data_old_by_id.keys())
new_ids = set(data_new_by_id.keys())

new_only_ids = new_ids - old_ids
old_only_ids = old_ids - new_ids
both_ids = old_ids & new_ids

assert len(new_only_ids) + len(both_ids) == len(new_ids)
assert len(old_only_ids) + len(both_ids) == len(old_ids)

len(new_only_ids), len(old_only_ids)
# Out:
# (666, 50)

# %%
for removed_ad_id in old_only_ids:
    removed_ad = data_old_by_id[removed_ad_id]
    print()
    print(removed_ad_id)
    print(removed_ad['ad_creative_body'])
# Out:
# 455135145222953
# “Les Femmes dans le milieu de la culture : quels enjeux professionnels, partage d’expériences.”
#
# Une table ronde pour évoquer la représentation des femmes dans les métiers de la culture et leurs défis d’aujourd’hui.
# Programmé par She Moves Events sur l’invitation du Club Femmes ici et ailleurs.
#
# 🇨🇦😃Le Canada a ouvert ses portes aux immigrants 2019-2020.
#
# Inscrivez-vous maintenant -> et recevez un téléphone de nos experts en immigration.
#
# 👉Une entreprise réglementée avec 25 ans d’expérience vous guidera en toute sécurité jusqu’à ce que vous arriviez au Canada!
#
# 349469622347329
# Guatemala is banning plastic and challenging big industry.
#
# Curious? http://owl.li/Umcv30ojFRe
#
# 1615467565222613
# Produire de l’électricité en minimisant l’impact environnemental : notre première centrale 100% biomasse d'Outre-Mer👇
#
# 294338384580230
# THTC's most notorious print, 'Get Rich...' inked by Mau Mau, is now partnered with Refugee Community Kitchen. 20% of sales from this design support RCK's vital work, feeding vulnerable families and individuals in need.
#
# 327768994541824
# NOUVELLE VIDEO !!
#
# PARIS, TOURNAGE AVEC PIERRE CROCE - VLOG #3
#
# Indice: J'ai maintenant le corps d'une personne de 80 ans.
#
# http://bit.ly/2NaRxbo
#
# 2168567070123061
# Ils sont encore des enfants, des adolescents et risquent d’être jetés à la rue puis expulsés parce qu’ils sont étrangers.
#
# ➡️ Aidez-nous à stopper cette injustice : signez la pétition adressée au Premier Ministre ! ✍️
#
# 313762432621390
# Produire de l’électricité en minimisant l’impact environnemental : notre première centrale 100% biomasse d'Outre-Mer👇
#
# 1987745491534031
# THTC's most notorious print, 'Get Rich...' inked by Mau Mau, is now partnered with Refugee Community Kitchen. 20% of sales from this design support RCK's vital work, feeding vulnerable families and individuals in need.
#
# 615229228939621
# Ridder Management Systems: minimize input errors, cut on labor costs, improve worker productivity and increase job satisfaction.
#
# 2129453120482372
# La transition énergétique dans les zones déconnectées des réseaux électriques continentaux comment ça se passe ?  Découvrez notre article sur Galion 2, la première centrale 100% biomasse d’Outre-mer qui fournit une énergie renouvelable, décarbonée et sans intermittence en Martinique ! ⤵️
#
# 599989070519340
# Produire de l’électricité en minimisant l’impact environnemental : notre première centrale 100% biomasse d'Outre-Mer👇
#
# 356597405065872
# Découvrez notre article sur Galion 2, la 1ère centrale 100% biomasse d’Outre-mer qui fournit une énergie renouvelable et décarbonée en Martinique 👇
#
# 297529204272390
# ☀️ Chaque année, la Terre reçoit 1.070.000 pétawatts-heures d'énergie solaire : découvrez comment nous valorisons cette énergie inépuisable, renouvelable et disponible partout ⤵️
#
# 334082787226349
# NOUVELLE VIDEO !
# CRISE TURQUE : L'ORIGINE D'UN KRACH
#
# Cette semaine la Turquie est revenue au premier plan dans l'actualité mondiale et financière. La peur d'une crise de grande ampleur plombant les marchés mondiaux.
#
# A part Trump, sais-tu d'où vient cette crise ? Erdogan en est à l'origine. On analyse tout maintenant !
#
# Clique sur ce lien !
#
# http://bit.ly/2MnohBj
#
# 325927684591964
# THTC's most notorious print, 'Get Rich...' inked by Mau Mau, is now partnered with Refugee Community Kitchen. 20% of sales from this design support RCK's vital work, feeding vulnerable families and individuals in need.
#
# 2177383829017125
# THTC's most notorious print, 'Get Rich...' inked by Mau Mau, is now partnered with Refugee Community Kitchen. 15% of sales from this design support RCK's vital work, feeding vulnerable families and individuals in need.
#
# 1140083106162863
# THTC's most notorious print, 'Get Rich...' inked by Mau Mau, is now partnered with Refugee Community Kitchen. 15% of sales from this design support RCK's vital work, feeding vulnerable families and individuals in need.
#
# 656879938076958
# UE: Démocratie à deux vitesses. En RDC, puisqu'il s'agit des noirs africains, l'UE refuse de reconnaître le VOTE du
# Vainqueur(62 %) au profit de celui qui n'a eu que 16 %.
# Au Venezuela : un empressement pour soutenir Gaïdo !
# Et au "pays" des droits de l'homme: le Ministre allègue
# une Spécificité "africaine" pour ce qui n'est, en réalité, qu' un Mépris du noir...
#
# 1822764624496122
# NOUVELLE VIDEO !!
#
# PARIS, TOURNAGE AVEC PIERRE CROCE - VLOG #3
#
# Indice: J'ai maintenant le corps d'une personne de 80 ans.
#
# http://bit.ly/2NaRxbo
#
# 2193676430946889
# 🇨🇦😃Le Canada a ouvert ses portes aux immigrants 2019-2020.
#
# Inscrivez-vous maintenant -> et recevez un téléphone de nos experts en immigration.
#
# 👉Une entreprise réglementée avec 25 ans d’expérience vous guidera en toute sécurité jusqu’à ce que vous arriviez au Canada!
#
# 383314132505078
# UE: Démocratie à deux vitesses. En RDC, puisqu'il s'agit des noirs africains, l'UE refuse de reconnaître le VOTE du
# Vainqueur(62 %) au profit de celui qui n'a eu que 16 %.
# Au Venezuela : un empressement pour soutenir Gaïdo !
# Et au "pays" des droits de l'homme: le Ministre allègue
# une Spécificité "africaine" pour ce qui n'est, en réalité, qu' un Mépris du noir...
#
# 267094667541286
# UE: Démocratie à deux vitesses. En RDC, puisqu'il s'agit des noirs africains, l'UE refuse de reconnaître le VOTE du
# Vainqueur(62 %) au profit de celui qui n'a eu que 16 %.
# Au Venezuela : un empressement pour soutenir Gaïdo !
# Et au "pays" des droits de l'homme: le Ministre allègue
# une Spécificité "africaine" pour ce qui n'est, en réalité, qu' un Mépris du noir...
#
# 1045324478995298
# UE: Démocratie à deux vitesses. En RDC, puisqu'il s'agit des noirs africains, l'UE refuse de reconnaître le VOTE du
# Vainqueur(62 %) au profit de celui qui n'a eu que 16 %.
# Au Venezuela : un empressement pour soutenir Gaïdo !
# Et au "pays" des droits de l'homme: le Ministre allègue
# une Spécificité "africaine" pour ce qui n'est, en réalité, qu' un Mépris du noir...
#
# 2252155671672809
# UE: Démocratie à deux vitesses. En RDC, puisqu'il s'agit des noirs africains, l'UE refuse de reconnaître le VOTE du
# Vainqueur(62 %) au profit de celui qui n'a eu que 16 %.
# Au Venezuela : un empressement pour soutenir Gaïdo !
# Et au "pays" des droits de l'homme: le Ministre allègue
# une Spécificité "africaine" pour ce qui n'est, en réalité, qu' un Mépris du noir...
#
# 453147615454784
# In Europe you can choose! #Olabambala
#
# 402742493850457
# UE: Démocratie à deux vitesses. En RDC, puisqu'il s'agit des noirs africains, l'UE refuse de reconnaître le VOTE du
# Vainqueur(62 %) au profit de celui qui n'a eu que 16 %.
# Au Venezuela : un empressement pour soutenir Gaïdo !
# Et au "pays" des droits de l'homme: le Ministre allègue
# une Spécificité "africaine" pour ce qui n'est, en réalité, qu' un Mépris du noir...
#
# 317526348920612
# Do you have a great idea for new a way to teach Holocaust history? A creative concept for using technology to commemorate the Holocaust? Our Innovation Hub can help you develop and implement your idea.
# Join us in the first incubator of its kind.
#
# 572312883269802
# THTC's most notorious print, 'Get Rich...' inked by Mau Mau, is now partnered with Refugee Community Kitchen. 15% of sales from this design support RCK's vital work, feeding vulnerable families and individuals in need.
#
# 293926261512823
# THTC's most notorious print, 'Get Rich...' inked by Mau Mau, is now partnered with Refugee Community Kitchen. 15% of sales from this design support RCK's vital work, feeding vulnerable families and individuals in need.
#
# 864483987223797
# Selon @the_oecd, l’avenir du travail se joue maintenant. En France, 16,4% des emplois sont fortement automatisables d’ici 20 ans contre 14% en moyenne dans les pays de l’OCDE. Même si le nombre d’emplois devrait rester stable, leur qualité pourrait se détériorer…
#
# Et vous, comment voyez-vous l’avenir du travail ?
#
# L'étude est à retrouver sur :
# oe.cd/fow
# ___
# Les faits,
# rien que les faits,
# retour aux sources.
#
# 310617589638064
# NOUVELLE VIDEO !
#
# WARREN BUFFETT INVESTISSEUR DEVENU LEGENDE !
#
# 3 ème homme le plus riche du monde, il a commencé à investir à 11 ans en partant de son travail de livreur de journaux !
#
# Une histoire incroyable et une philosophie d'investissement implacable.
#
# Découvre qui est Warren Buffett !
#
# http://bit.ly/2PAR6eY
#
# 542043662868175
# Découvrez notre article sur Galion 2, la 1ère centrale 100% biomasse d’Outre-mer qui fournit une énergie renouvelable et décarbonée en Martinique 👇
#
# 1201410980034297
# Découvrez notre article sur Galion 2, la 1ère centrale 100% biomasse d’Outre-mer qui fournit une énergie renouvelable et décarbonée en Martinique 👇
#
# 2422561531101345
# “Les Femmes dans le milieu de la culture : quels enjeux professionnels, partage d’expériences.”
#
# Une table ronde pour évoquer la représentation des femmes dans les métiers de la culture et leurs défis d’aujourd’hui.
# Programmé par She Moves Events sur l’invitation du Club Femmes ici et ailleurs.
#
# Comment les artistes professionnelles vivent-elles le fait de devoir s’imposer dans un univers au pouvoir décisionnel essentiellement masculin ? Quelles difficultés rencontrent-elles pour être programmées, financées ou publiées ?
# Kylie Walters, danseuse, chorégraphe, performer et directrice de She Moves Events se penche précisément sur ces questions dans un échange avec des artistes (et féministes) reconnues à l’international et basées à Lyon : l’illustratrice Diglee, la DJ et productrice de POLAAR Sounds Flore Morfin, la comédienne Mélanie Bestel de l’Avantage du Doute et Olivier Conan, directeur de  l’Amphithéâtre de l’Opéra de Lyon et du programme Opéra Underground.
#
# Avec la participation de Diglee Glittering Bitch, DJ Flore, Olivier Conan, Mélanie Bestel et  l’association H/F (Françoise Barret & Solène Krystkowiak)
# Modération : Kylie Walters, directrice de She Moves Events
#
# 399192543979028
# NOUVELLE VIDEO - LES 10 PLUS GRANDES BANQUES DU MONDE !
#
# 25 000 milliards de dollars ça fait combien de zéro ?
#
# Dans le top, deux banques Françaises et ce n'est pas du tout celles auxquelles tu penses !
#
# http://bit.ly/2K33dyB
#
# 622985284816875
# Ridder Management Systems: minimize input errors, cut on labor costs, improve worker productivity and increase job satisfaction.
#
# 2202862489780979
# Ils sont encore des enfants, des adolescents et risquent d’être jetés à la rue puis expulsés parce qu’ils sont étrangers.
#
# ➡️ Aidez-nous à stopper cette injustice : signez la pétition adressée au Premier Ministre ! ✍️
#
# 318153242184594
# « Grand Débat » : une vaste fumisterie
#
# Le 10 décembre dernier, dans un contexte de véritable crise sociale, le Président de la République annonçait, solennellement, la tenue d'un Grand Débat afin de prendre « le pouls des Français », déclarait-il, suscitant l'espoir d'une véritable refonte de son orientation politique pour la deuxième moitié de son quinquennat et promettant, selon ses propres termes, que « rien ne serait plus jamais comme avant ».
#
# Quatre mois plus tard, il y a trois jours, à l'occasion d'une conférence de presse grandiloquente, fort de mesures censées dissiper le mouvement des Gilets Jaunes, le Président assure, la main sur le coeur, avoir « entendu » les Français et fait le constat de revendications largement partagées.
#
# Pourtant, Emmanuel Macron n'a, à la stupéfaction générale, retenu AUCUNE des revendications portées par le mouvement social, se livrant à un véritable exercice d'autosatisfaction et préférant balayer d'un revers de la main les attentes relatives au rétablissement de l'ISF, à la mise à contribution des grandes fortunes et des grandes capitalisations boursières et au Référendum d'Initiative Citoyenne (RIC).
#
# Cette conférence de presse était l'occasion d'un véritable tournant du quinquennat. Il n'en est rien. A quoi donc a servi ce « Grand Débat » si ce n'est à consacrer la parole d'un homme imbu de lui-même et à conduire une coûteuse opération de communication apparentée, au bout du compte, à une vaste fumisterie nourrissant de fait une défiance déjà largement entamée chez nos concitoyens à l'endroit de nos gouvernants.

# %%
for ad_id in both_ids:
    old_ad = data_old_by_id[ad_id]
    new_ad = data_new_by_id[ad_id]
    
    removed_fields = set(old_ad)-set(new_ad)
    if removed_fields:
        print('Ad {} had this fields removed: {}'.format(
            ad_id,
            removed_fields,
        ))
# Out:
# Ad 730293687402860 had this fields removed: {'impressions'}
# Ad 335683300330725 had this fields removed: {'impressions'}
# Ad 432725190848334 had this fields removed: {'impressions'}
# Ad 432423704207011 had this fields removed: {'impressions'}
# Ad 452294458850897 had this fields removed: {'impressions'}
# Ad 426058758249628 had this fields removed: {'impressions'}
# Ad 451590282263446 had this fields removed: {'impressions'}
# Ad 1745413905604254 had this fields removed: {'impressions'}
# Ad 679159952539804 had this fields removed: {'impressions'}
# Ad 844745269217027 had this fields removed: {'impressions'}
# Ad 2309975952589654 had this fields removed: {'impressions'}
# Ad 433916807385255 had this fields removed: {'impressions'}
# Ad 422848274945365 had this fields removed: {'impressions'}
# Ad 645332255915681 had this fields removed: {'impressions'}
# Ad 2672860776119892 had this fields removed: {'impressions'}
