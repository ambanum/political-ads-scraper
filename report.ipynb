# %%
import pandas as pd

# %%
report_to_date = pd.read_csv('report-gb/FacebookAdLibraryReportGB2019-05-11SpendingToDate.csv')

# %%
report_week = pd.read_csv('report-gb/FacebookAdLibraryReportGB2019-05-11ThisWeekSpending.csv')

# %%
report_to_date
# Out:
#                                         Page Name  \
# 0                                People's Vote UK
# 1                                Britain's Future
# 2                                Best For Britain
# 3                                   UK government
# 4                               Liberal Democrats
# 5                                   Conservatives
# 6                         Electoral Commission UK
# 7                                The Labour Party
# 8                                The Brexit Party
# 9                                  We are the 52%
# 10                                     38 Degrees
# 11                           Friends of the Earth
# 12        International Rescue Committee - Europe
# 13                                  Right To Vote
# 14                           Friends of the Earth
# 15                           Friends of the Earth
# 16                          The Independent Group
# 17                Ben Houchen - Tees Valley Mayor
# ...

# %%
report_to_date[report_to_date['Page Name']=='Pinksixty']
# Out:
#       Page Name      Disclaimer Amount Spent  Number of Ads in Library
# 2454  Pinksixty  Leeze Lawrence         ≤100                        16

# %%
sum(report_week['Number of Ads in Library'])
# Out:
# 4147

# %%
report_week[report_week['Page Name']=='Pinksixty']
# Out:
#      Page Name      Disclaimer Amount Spent  Number of Ads in Library
# 359  Pinksixty  Leeze Lawrence         ≤100                         5
