# %%
import tempfile
import zipfile
import datetime
import json
import pathlib
import operator
import collections

import pandas as pd

from google_fetch import config

# %%
def read_bundle(bundle_path):
    fetch_datetime = datetime.datetime.strptime(
        bundle_path.stem,
        'google-political-ads-transparency-bundle_%Y-%m-%d_%H-%M-%S',
    )

    with tempfile.TemporaryDirectory() as tmpdirname:
        tmp_dir = pathlib.Path(tmpdirname)

        with zipfile.ZipFile(bundle_path, "r") as zip_ref:
            zip_ref.extractall(tmpdirname)

            assert set([
                element.name
                for element in tmp_dir.iterdir()
            ]) == {'google-political-ads-transparency-bundle'}

            data_dir = tmp_dir / 'google-political-ads-transparency-bundle'
            assert set([
                element.name
                for element in data_dir.iterdir()
            ]) == {
                'README.txt',
                'google-political-ads-advertiser-stats.csv',
                'google-political-ads-advertiser-weekly-spend.csv',
                'google-political-ads-campaign-targeting.csv',
                'google-political-ads-creative-stats.csv',
                'google-political-ads-geo-spend.csv',
                'google-political-ads-top-keywords-history.csv',
            }

            bundle_data = {}

            with open(data_dir / 'README.txt', 'r') as f:
                bundle_data['README.txt'] = f.read()

            for key in [
                'google-political-ads-advertiser-stats.csv',
                'google-political-ads-advertiser-weekly-spend.csv',
                'google-political-ads-campaign-targeting.csv',
                'google-political-ads-creative-stats.csv',
                'google-political-ads-geo-spend.csv',
                'google-political-ads-top-keywords-history.csv',
            ]:
                bundle_data[key] = pd.read_csv(
                    data_dir / key,
                    dtype=str,
                    keep_default_na=False,
                    na_values={},
                )

    return fetch_datetime, bundle_data

# %%
for bundle_path in sorted(list((config.DATA_DIR / 'google').iterdir())):
    print(bundle_path)
# Out:
# /home/michel/projects/desinfo/political-ads-scraper/data/google/1
# /home/michel/projects/desinfo/political-ads-scraper/data/google/2
# /home/michel/projects/desinfo/political-ads-scraper/data/google/google-political-ads-transparency-bundle_2019-06-14_14-32-03.zip
# /home/michel/projects/desinfo/political-ads-scraper/data/google/google-political-ads-transparency-bundle_2019-06-18_14-18-01.zip

# %%
bundle_path_1 = pathlib.Path('/home/michel/projects/desinfo/political-ads-scraper/data/google/google-political-ads-transparency-bundle_2019-06-14_14-32-03.zip')
bundle_path_2 = pathlib.Path('/home/michel/projects/desinfo/political-ads-scraper/data/google/google-political-ads-transparency-bundle_2019-06-18_14-18-01.zip')
fetch_datetime_1, bundle_data_1 = read_bundle(bundle_path_1)
fetch_datetime_2, bundle_data_2 = read_bundle(bundle_path_2)

# %%
bundle_data_1['README.txt'] == bundle_data_2['README.txt']
# Out:
# True

# %%
key = 'google-political-ads-creative-stats.csv'
df_1 = bundle_data_1[key]
df_2 = bundle_data_2[key]

assert list(df_1.columns) == list(df_2.columns)

# A few ads were run by distinct advertisers, for instance:
# https://transparencyreport.google.com/political-ads/advertiser/AR185084640594231296/creative/CR275167628257918976
# https://transparencyreport.google.com/political-ads/advertiser/AR242125929453715456/creative/CR275167628257918976
duplicate_ad_ids_1 = [
    ad_id
    for ad_id, count in collections.Counter(df_1['Ad_ID']).items()
    if count > 1
]
duplicate_ad_ids_2 = [
    ad_id
    for ad_id, count in collections.Counter(df_2['Ad_ID']).items()
    if count > 1
]
assert set(duplicate_ad_ids_1) == set(duplicate_ad_ids_2)

print('The following ads were run by several advertisers: {}'.format(duplicate_ad_ids_1))


indexes = ['Ad_ID', 'Advertiser_ID']
df_1.set_index(indexes, inplace=True)
df_2.set_index(indexes, inplace=True)

ids_1 = set(df_1.index)
ids_2 = set(df_2.index)

assert len(ids_1) == len(df_1)
assert len(ids_2) == len(df_2)

removed_ids = ids_1 - ids_2
added_ids = ids_2 - ids_1
common_ids = ids_1 & ids_2
assert len(ids_1) + len(added_ids) - len(removed_ids) == len(ids_2)
assert len(ids_1 | ids_2) == len(common_ids) + len(added_ids) + len(removed_ids)

print('{} ads were removed, {} were added'.format(len(removed_ids), len(added_ids)))

assert len(removed_ids) == len(added_ids)

assert set(map(operator.itemgetter(0), removed_ids)) == set(map(operator.itemgetter(0), added_ids))

# For 65 ads, neither the old nor the add can be viewed:
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR100348028220604416
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696/creative/CR103736173301596160

# Same for the advertisers:
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696

for removed_id, added_id in zip(sorted(removed_ids), sorted(added_ids)):
    print('{}\n    by {}\nwas replaced by\n{}    by {}\n'.format(
        'https://transparencyreport.google.com/political-ads/advertiser/{}/creative/{}'.format(removed_id[1], removed_id[0]),
        'https://transparencyreport.google.com/political-ads/advertiser/{}'.format(removed_id[1]),
        'https://transparencyreport.google.com/political-ads/advertiser/{}/creative/{}'.format(added_id[1], added_id[0]),
        'https://transparencyreport.google.com/political-ads/advertiser/{}'.format(added_id[1]),
    ))

for line_id in list(common_ids):
    modifications = df_1.loc[line_id] != df_2.loc[line_id]
    modified_columns = list(modifications[modifications].axes[0])
    if modified_columns:
        print('Ad {} has be modified'.format(line_id))
# Out:
# The following ads were run by several advertisers: ['CR100007454493900800', 'CR101180908278644736', 'CR102860962045886464', 'CR106855212911689728', 'CR109616361486942208', 'CR110281291143839744', 'CR110562766120550400', 'CR11307652457955328', 'CR114455037282877440', 'CR114762075904933888', 'CR115985557468741632', 'CR117423718677872640', 'CR117779135811551232', 'CR118905035718393856', 'CR119240111886958592', 'CR120180469206614016', 'CR120593885578657792', 'CR121438310508789760', 'CR123549372834119680', 'CR123954817746862080', 'CR124112322787540992', 'CR124777252444438528', 'CR130445509763530752', 'CR13466268661186560', 'CR135485671065255936', 'CR136919434227875840', 'CR137200909204586496', 'CR137623121669652480', 'CR138872991512526848', 'CR140069260163547136', 'CR140139628907724800', 'CR140421103884435456', 'CR146568748273238016', 'CR146895028348780544', 'CR147048959976669184', 'CR147193270877814784', 'CR151328259231973376', 'CR154652357760647168', 'CR156200470132555776', 'CR157520708719607808', 'CR157872552440496128', 'CR158272774673006592', 'CR159155957388017664', 'CR159561402300760064', 'CR160141119806504960', 'CR161157893184290816', 'CR161953939602800640', 'CR162815132085256192', 'CR165402008067506176', 'CR165480348270985216', 'CR165629881852362752', 'CR166474306782494720', 'CR166739014206881792', 'CR167653807881191424', 'CR168146389090435072', 'CR169272288997277696', 'CR171514468084219904', 'CR171540856363286528', 'CR173402054671204352', 'CR17416539061878784', 'CR17424510521180160', 'CR177012850856820736', 'CR177940838670663680', 'CR181673955524870144', 'CR182290506670145536', 'CR184057696733888512', 'CR185201188826775552', 'CR186864475041693696', 'CR187162717570727936', 'CR187286687506759680', 'CR187980754221793280', 'CR188834799878668288', 'CR189045906111201280', 'CR190853503227265024', 'CR191134978203975680', 'CR192792217104941056', 'CR193175671785127936', 'CR193901349459460096', 'CR195184754406981632', 'CR195744130947612672', 'CR197982736621764608', 'CR202486336249135104', 'CR203066053754880000', 'CR205138358295330816', 'CR205301086016241664', 'CR206057550016151552', 'CR206839577661407232', 'CR206897576899772416', 'CR207130673364860928', 'CR208176583800782848', 'CR210169723504033792', 'CR212495465474686976', 'CR214497401270960128', 'CR215693669921980416', 'CR220922947223683072', 'CR223613727054757888', 'CR224441384432566272', 'CR226991426775285760', 'CR228829810216927232', 'CR232480188821143552', 'CR237248495872901120', 'CR240502225657397248', 'CR242504161453670400', 'CR243089101639647232', 'CR243149849657081856', 'CR243879925377925120', 'CR244724350308057088', 'CR247500342290284544', 'CR248239214104150016', 'CR248591057825038336', 'CR248718601173860352', 'CR251124332615434240', 'CR252166669638565888', 'CR256107319312515072', 'CR256546299329904640', 'CR257725800428601344', 'CR258372313265733632', 'CR259220311608655872', 'CR259440213934211072', 'CR259721688910921728', 'CR261433353637462016', 'CR26225826223620096', 'CR262946281637281792', 'CR262958651143094272', 'CR265114518567256064', 'CR265316004073046016', 'CR265975711049711616', 'CR266570271962431488', 'CR267309143776296960', 'CR270462543124758528', 'CR271402900444413952', 'CR272308898025701376', 'CR275167628257918976', 'CR277234710118137856', 'CR281158592239763456', 'CR282003017169895424', 'CR285116009466036224', 'CR286241909372878848', 'CR286945596814655488', 'CR287913991680819200', 'CR289440113820172288', 'CR289932695029415936', 'CR29114518147694592', 'CR291410438657146880', 'CR293419521279000576', 'CR296230697633316864', 'CR298693603679535104', 'CR29958943077826560', 'CR299735940702666752', 'CR300315658208411648', 'CR301684275307085824', 'CR303887696609148928', 'CR304943227771813888', 'CR305506177725235200', 'CR306275835864678400', 'CR307255775602933760', 'CR309143362189918208', 'CR310445183957204992', 'CR311011707323416576', 'CR312965264608067584', 'CR314855599974121472', 'CR3218820290314240', 'CR322974393833619456', 'CR323818818763751424', 'CR327759468437700608 ...
# 65 ads were removed, 65 were added
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR100348028220604416
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR100348028220604416    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920/creative/CR103736173301596160
#     by https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696/creative/CR103736173301596160    by https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696
#
# https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920/creative/CR10541567731302400
#     by https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696/creative/CR10541567731302400    by https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696
#
# https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920/creative/CR106958292126793728
#     by https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696/creative/CR106958292126793728    by https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696
#
# https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744/creative/CR112992961695842304
#     by https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096/creative/CR112992961695842304    by https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696/creative/CR119879203020603392
#     by https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656/creative/CR119879203020603392    by https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680/creative/CR125729429514092544
#     by https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032/creative/CR125729429514092544    by https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032
#
# https://transparencyreport.google.com/political-ads/advertiser/AR314918547014811648/creative/CR136528008088387584
#     by https://transparencyreport.google.com/political-ads/advertiser/AR314918547014811648
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR160072125451862016/creative/CR136528008088387584    by https://transparencyreport.google.com/political-ads/advertiser/AR160072125451862016
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR1409573906808832
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR1409573906808832    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744/creative/CR147192171366187008
#     by https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096/creative/CR147192171366187008    by https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096
#
# https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920/creative/CR151689723679604736
#     by https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696/creative/CR151689723679604736    by https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR155860171283759104
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR155860171283759104    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR163956974910701568
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR163956974910701568    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696/creative/CR172092811200430080
#     by https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656/creative/CR172092811200430080    by https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744/creative/CR172736025502679040
#     by https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096/creative/CR172736025502679040    by https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096
#
# https://transparencyreport.google.com/political-ads/advertiser/AR224846554467401728/creative/CR185409546280239104
#     by https://transparencyreport.google.com/political-ads/advertiser/AR224846554467401728
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR412273704584609792/creative/CR185409546280239104    by https://transparencyreport.google.com/political-ads/advertiser/AR412273704584609792
#
# https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680/creative/CR197895325447356416
#     by https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032/creative/CR197895325447356416    by https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR207308519370653696
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR207308519370653696    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920/creative/CR233669310646583296
#     by https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696/creative/CR233669310646583296    by https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696
#
# https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744/creative/CR236982688936886272
#     by https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096/creative/CR236982688936886272    by https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR244885428761526272
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR244885428761526272    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR251359353225871360
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR251359353225871360    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920/creative/CR254028967458111488
#     by https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696/creative/CR254028967458111488    by https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696
#
# https://transparencyreport.google.com/political-ads/advertiser/AR368961742543257600/creative/CR25733245014376448
#     by https://transparencyreport.google.com/political-ads/advertiser/AR368961742543257600
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR124043328432898048/creative/CR25733245014376448    by https://transparencyreport.google.com/political-ads/advertiser/AR124043328432898048
#
# https://transparencyreport.google.com/political-ads/advertiser/AR224846554467401728/creative/CR261970739945537536
#     by https://transparencyreport.google.com/political-ads/advertiser/AR224846554467401728
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR412273704584609792/creative/CR261970739945537536    by https://transparencyreport.google.com/political-ads/advertiser/AR412273704584609792
#
# https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680/creative/CR283322980879040512
#     by https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032/creative/CR283322980879040512    by https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696/creative/CR286793864210022400
#     by https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656/creative/CR286793864210022400    by https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696/creative/CR290030826442194944
#     by https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656/creative/CR290030826442194944    by https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR310187623358398464
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR310187623358398464    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR188817757448437760/creative/CR312872080997613568
#     by https://transparencyreport.google.com/political-ads/advertiser/AR188817757448437760
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR322201712037199872/creative/CR312872080997613568    by https://transparencyreport.google.com/political-ads/advertiser/AR322201712037199872
#
# https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680/creative/CR316677765619253248
#     by https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032/creative/CR316677765619253248    by https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032
#
# https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744/creative/CR317203057299423232
#     by https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096/creative/CR317203057299423232    by https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR321728097403535360
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR321728097403535360    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR224846554467401728/creative/CR323085994263838720
#     by https://transparencyreport.google.com/political-ads/advertiser/AR224846554467401728
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR412273704584609792/creative/CR323085994263838720    by https://transparencyreport.google.com/political-ads/advertiser/AR412273704584609792
#
# https://transparencyreport.google.com/political-ads/advertiser/AR152788960429473792/creative/CR326774306019213312
#     by https://transparencyreport.google.com/political-ads/advertiser/AR152788960429473792
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR340216110546681856/creative/CR326774306019213312    by https://transparencyreport.google.com/political-ads/advertiser/AR340216110546681856
#
# https://transparencyreport.google.com/political-ads/advertiser/AR368961742543257600/creative/CR360301439207079936
#     by https://transparencyreport.google.com/political-ads/advertiser/AR368961742543257600
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR124043328432898048/creative/CR360301439207079936    by https://transparencyreport.google.com/political-ads/advertiser/AR124043328432898048
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696/creative/CR371658569688285184
#     by https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656/creative/CR371658569688285184    by https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR371966982699876352
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR371966982699876352    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680/creative/CR372122563595206656
#     by https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032/creative/CR372122563595206656    by https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696/creative/CR374895531920457728
#     by https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656/creative/CR374895531920457728    by https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744/creative/CR375116533757640704
#     by https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096/creative/CR375116533757640704    by https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096
#
# https://transparencyreport.google.com/political-ads/advertiser/AR44702569372581888/creative/CR38813310216306688
#     by https://transparencyreport.google.com/political-ads/advertiser/AR44702569372581888
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR556388892660465664/creative/CR38813310216306688    by https://transparencyreport.google.com/political-ads/advertiser/AR556388892660465664
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR391533891627778048
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR391533891627778048    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR393781293394952192
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR393781293394952192    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR399837403440742400
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR399837403440742400    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920/creative/CR407128265044525056
#     by https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696/creative/CR407128265044525056    by https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696
#
# https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680/creative/CR415053269979627520
#     by https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032/creative/CR415053269979627520    by https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR417570326973513728
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR417570326973513728    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR152788960429473792/creative/CR419855387013939200
#     by https://transparencyreport.google.com/political-ads/advertiser/AR152788960429473792
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR340216110546681856/creative/CR419855387013939200    by https://transparencyreport.google.com/political-ads/advertiser/AR340216110546681856
#
# https://transparencyreport.google.com/political-ads/advertiser/AR368961742543257600/creative/CR437566320314155008
#     by https://transparencyreport.google.com/political-ads/advertiser/AR368961742543257600
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR124043328432898048/creative/CR437566320314155008    by https://transparencyreport.google.com/political-ads/advertiser/AR124043328432898048
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696/creative/CR44021696797081600
#     by https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656/creative/CR44021696797081600    by https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744/creative/CR446048227888726016
#     by https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096/creative/CR446048227888726016    by https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096
#
# https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920/creative/CR446346745295667200
#     by https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696/creative/CR446346745295667200    by https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696/creative/CR473833986234253312
#     by https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656/creative/CR473833986234253312    by https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR484697710872494080
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR484697710872494080    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696/creative/CR495419598510751744
#     by https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656/creative/CR495419598510751744    by https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR477048133600149504/creative/CR499752773835816960
#     by https://transparencyreport.google.com/political-ads/advertiser/AR477048133600149504
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR178086523961344000/creative/CR499752773835816960    by https://transparencyreport.google.com/political-ads/advertiser/AR178086523961344000
#
# https://transparencyreport.google.com/political-ads/advertiser/AR188817757448437760/creative/CR517478000787193856
#     by https://transparencyreport.google.com/political-ads/advertiser/AR188817757448437760
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR322201712037199872/creative/CR517478000787193856    by https://transparencyreport.google.com/political-ads/advertiser/AR322201712037199872
#
# https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920/creative/CR529030019704422400
#     by https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696/creative/CR529030019704422400    by https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696/creative/CR554758042038566912
#     by https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656/creative/CR554758042038566912    by https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520/creative/CR555413900724535296
#     by https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080/creative/CR555413900724535296    by https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696/creative/CR559824591619358720
#     by https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656/creative/CR559824591619358720    by https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR224846554467401728/creative/CR571593214327259136
#     by https://transparencyreport.google.com/political-ads/advertiser/AR224846554467401728
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR412273704584609792/creative/CR571593214327259136    by https://transparencyreport.google.com/political-ads/advertiser/AR412273704584609792
#
# https://transparencyreport.google.com/political-ads/advertiser/AR152788960429473792/creative/CR93977732727177216
#     by https://transparencyreport.google.com/political-ads/advertiser/AR152788960429473792
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR340216110546681856/creative/CR93977732727177216    by https://transparencyreport.google.com/political-ads/advertiser/AR340216110546681856
#
# https://transparencyreport.google.com/political-ads/advertiser/AR188817757448437760/creative/CR97191880093073408
#     by https://transparencyreport.google.com/political-ads/advertiser/AR188817757448437760
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR322201712037199872/creative/CR97191880093073408    by https://transparencyreport.google.com/political-ads/advertiser/AR322201712037199872

# %%
key = 'google-political-ads-advertiser-stats.csv'
df_1 = bundle_data_1[key]
df_2 = bundle_data_2[key]

assert list(df_1.columns) == list(df_2.columns)

indexes = 'Advertiser_ID'
df_1.set_index(indexes, inplace=True)
df_2.set_index(indexes, inplace=True)
ids_1 = set(df_1.index)
ids_2 = set(df_2.index)

assert len(ids_1) == len(df_1)
assert len(ids_2) == len(df_2)

removed_ids = ids_1 - ids_2
added_ids = ids_2 - ids_1
common_ids = ids_1 & ids_2
assert len(ids_1) + len(added_ids) - len(removed_ids) == len(ids_2)
assert len(ids_1 | ids_2) == len(common_ids) + len(added_ids) + len(removed_ids)

print('{} advertisers were removed, {} were added'.format(len(removed_ids), len(added_ids)))
assert len(removed_ids) == len(added_ids)

for removed_id, added_id in zip(sorted(removed_ids), sorted(added_ids)):
    print('{}\nwas replaced by\n{}\n'.format(
        'https://transparencyreport.google.com/political-ads/advertiser/{}'.format(removed_id),
        'https://transparencyreport.google.com/political-ads/advertiser/{}'.format(added_id),
    ))

for line_id in list(common_ids):
    modifications = df_1.loc[line_id] != df_2.loc[line_id]
    modified_columns = list(modifications[modifications].axes[0])
    if modified_columns:
        print('Line {} has be modified'.format(line_id))
# Out:
# 12 advertisers were removed, 12 were added
# https://transparencyreport.google.com/political-ads/advertiser/AR152788960429473792
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR124043328432898048
#
# https://transparencyreport.google.com/political-ads/advertiser/AR188817757448437760
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032
#
# https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR160072125451862016
#
# https://transparencyreport.google.com/political-ads/advertiser/AR224846554467401728
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR178086523961344000
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR322201712037199872
#
# https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR340216110546681856
#
# https://transparencyreport.google.com/political-ads/advertiser/AR314918547014811648
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR412273704584609792
#
# https://transparencyreport.google.com/political-ads/advertiser/AR368961742543257600
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696
#
# https://transparencyreport.google.com/political-ads/advertiser/AR44702569372581888
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR556388892660465664
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656
#
# https://transparencyreport.google.com/political-ads/advertiser/AR477048133600149504
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096
#
# https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920
# was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080

# %%
key = 'google-political-ads-advertiser-weekly-spend.csv'
df_1 = bundle_data_1[key]
df_2 = bundle_data_2[key]

assert list(df_1.columns) == list(df_2.columns)

indexes = ['Advertiser_ID', 'Week_Start_Date']
df_1.set_index(indexes, inplace=True)
df_2.set_index(indexes, inplace=True)

ids_1 = set(df_1.index)
ids_2 = set(df_2.index)

assert len(ids_1) == len(df_1)
assert len(ids_2) == len(df_2)

removed_ids = ids_1 - ids_2
added_ids = ids_2 - ids_1
common_ids = ids_1 & ids_2
assert len(ids_1) + len(added_ids) - len(removed_ids) == len(ids_2)
assert len(ids_1 | ids_2) == len(common_ids) + len(added_ids) + len(removed_ids)

print('{} lines were removed, {} were added'.format(len(removed_ids), len(added_ids)))
assert len(removed_ids) == len(added_ids)

old_advertisers = set(map(operator.itemgetter(0), removed_ids))
new_advertisers = set(map(operator.itemgetter(0), added_ids))

assert not old_advertisers & new_advertisers

print('Lines have been removed about the following advertisers:\n')
for advertiser_id in old_advertisers:
    print('{} ({})\n'.format(
        'https://transparencyreport.google.com/political-ads/advertiser/{}'.format(advertiser_id),
        [
            removed_id[1]
            for removed_id in removed_ids
            if removed_id[0] == advertiser_id
        ]
    ))

print('Lines have been added about the following advertisers:\n')
for advertiser_id in new_advertisers:
    print('{} ({})\n'.format(
        'https://transparencyreport.google.com/political-ads/advertiser/{}'.format(advertiser_id),
        [
            added_id[1]
            for added_id in added_ids
            if added_id[0] == advertiser_id
        ]
    ))

for line_id in list(common_ids):
    modifications = df_1.loc[line_id] != df_2.loc[line_id]
    modified_columns = list(modifications[modifications].axes[0])
    if modified_columns:
        print('Line {} has be modified'.format(line_id))
# Out:
# 72 lines were removed, 72 were added
# Lines have been removed about the following advertisers:
#
# https://transparencyreport.google.com/political-ads/advertiser/AR206832155957919744 (['2018-11-04', '2018-10-28'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR44702569372581888 (['2019-02-17', '2019-02-24', '2019-03-03', '2019-02-10', '2019-03-10'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR224846554467401728 (['2018-10-28', '2018-11-04'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR8673772353617920 (['2018-10-21', '2018-09-30', '2018-09-16', '2018-10-07', '2018-09-23', '2018-10-14', '2018-10-28'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR368961742543257600 (['2019-05-05', '2019-05-12'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR477048133600149504 (['2018-11-04', '2018-11-11'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR152788960429473792 (['2018-09-23', '2018-07-08', '2018-09-09', '2018-08-12', '2018-10-14', '2018-08-26', '2018-10-21', '2018-07-01', '2018-08-19', '2018-07-15', '2018-08-05', '2018-10-28', '2019-04-28', '2018-07-29', '2018-07-22', '2018-06-24', '2018-06-03', '2018-05-27', '2018-06-10', '2019-04-21', '2018-09-02', '2018-09-16', '2018-10-07', '2018-06-17', '2018-09-30'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR314918547014811648 (['2019-05-19', '2019-04-21', '2019-06-02', '2019-05-26', '2019-04-14', '2019-05-05', '2019-04-28', '2019-05-12'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR188817757448437760 (['2019-04-14'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR459033735090667520 (['2018-10-21', '2018-09-16', '2018-09-23', '2018-09-30', '2018-10-07', '2018-10-14', '2018-11-04', '2018-10-28'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR278889749995847680 (['2019-03-10', '2019-03-03'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR260875351486365696 (['2018-09-30', '2018-10-21', '2018-10-14', '2018-11-04', '2018-10-28', '2018-09-16', '2018-09-23', '2018-10-07'])
#
# Lines have been added about the following advertisers:
#
# https://transparencyreport.google.com/political-ads/advertiser/AR340216110546681856 (['2018-07-29', '2018-06-03', '2018-09-23', '2018-05-27', '2018-06-24', '2018-09-02', '2018-08-26', '2018-09-16', '2018-08-19', '2018-06-17', '2018-07-22', '2018-10-28', '2018-08-05', '2018-09-30', '2018-07-08', '2018-09-09', '2018-08-12', '2018-10-14', '2018-06-10', '2019-04-21', '2018-07-15', '2018-10-21', '2018-10-07', '2018-07-01', '2019-04-28'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032 (['2019-03-10', '2019-03-03'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR124043328432898048 (['2019-05-05', '2019-05-12'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR70000132904452096 (['2018-11-04', '2018-10-28'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR412273704584609792 (['2018-10-28', '2018-11-04'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR556388892660465664 (['2019-02-10', '2019-03-10', '2019-02-24', '2019-03-03', '2019-02-17'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR565396091915206656 (['2018-10-14', '2018-10-21', '2018-10-28', '2018-11-04', '2018-09-30', '2018-09-16', '2018-10-07', '2018-09-23'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR178086523961344000 (['2018-11-04', '2018-11-11'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696 (['2018-10-28', '2018-09-16', '2018-09-23', '2018-10-07', '2018-09-30', '2018-10-21', '2018-10-14'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR88014531413934080 (['2018-11-04', '2018-10-28', '2018-10-21', '2018-10-14', '2018-09-23', '2018-09-30', '2018-10-07', '2018-09-16'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR160072125451862016 (['2019-05-19', '2019-05-12', '2019-04-28', '2019-05-26', '2019-05-05', '2019-04-14', '2019-06-02', '2019-04-21'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR322201712037199872 (['2019-04-14'])

# %%
key = 'google-political-ads-campaign-targeting.csv'
df_1 = bundle_data_1[key]
df_2 = bundle_data_2[key]
assert list(df_1.columns) == list(df_2.columns)

duplicate_campaign_ids_1 = [
    campaign_id
    for campaign_id, count in collections.Counter(df_1['Campaign_ID']).items()
    if count > 1
]
duplicate_campaign_ids_2 = [
    campaign_id
    for campaign_id, count in collections.Counter(df_2['Campaign_ID']).items()
    if count > 1
]
assert set(duplicate_campaign_ids_1) == set(duplicate_campaign_ids_2)

print('The following campaigns were run by several advertisers: {}'.format(duplicate_campaign_ids_1))

indexes = ['Campaign_ID', 'Advertiser_ID']
df_1.set_index(indexes, inplace=True)
df_2.set_index(indexes, inplace=True)

ids_1 = set(df_1.index)
ids_2 = set(df_2.index)

assert len(ids_1) == len(df_1)
assert len(ids_2) == len(df_2)

removed_ids = ids_1 - ids_2
added_ids = ids_2 - ids_1
common_ids = ids_1 & ids_2
assert len(ids_1) + len(added_ids) - len(removed_ids) == len(ids_2)
assert len(ids_1 | ids_2) == len(common_ids) + len(added_ids) + len(removed_ids)

print('{} campaigns were removed, {} were added'.format(len(removed_ids), len(added_ids)))

assert len(removed_ids) == 0

# Campaign data can change. For example, End_Date or Gender_Targeting...
# Out:
# The following campaigns were run by several advertisers: ['CA102091303906443264', 'CA12561095713619968', 'CA129676676257808384', 'CA138683050878828544', 'CA168796475340357632', 'CA172438882485272576', 'CA186731709012639744', 'CA190399679802900480', 'CA20351410474319872', 'CA22429487450816512', 'CA239086054680821760', 'CA246748276336885760', 'CA267875667142508544', 'CA271464473095569408', 'CA274551901746364416', 'CA288141865465675776', 'CA288878538256285696', 'CA294897264906731520', 'CA301024568330420224', 'CA304169171585859584', 'CA311790161555881984', 'CA327975797350465536', 'CA328327641071353856', 'CA329242434745663488', 'CA345004208807739392', 'CA346688660621492224', 'CA34819609106317312', 'CA360199459503603712', 'CA360410565736136704', 'CA362455657363800064', 'CA364703059130974208', 'CA364876781968162816', 'CA366002681875005440', 'CA370034316136153088', 'CA373710258385715200', 'CA376226765623787520', 'CA388611664599056384', 'CA392461329685807104', 'CA399779679080284160', 'CA412255562642751488', 'CA418399633618763776', 'CA418746254659420160', 'CA419573912037228544', 'CA430005253727846400', 'CA474126456327241728', 'CA482533322233217024', 'CA487690856401207296', 'CA490803848697348096', 'CA495791233440940032', 'CA50187758005649408', 'CA508818247206830080', 'CA512460654351745024', 'CA51567370220601344', 'CA526832645716312064', 'CA549615351277551616', 'CA552170616300503040', 'CA565113242548961280', 'CA570663577245974528', 'CA66604291242065920', 'CA67808531352387584', 'CA71107890869436416', 'CA72796740729700352', 'CA78645317955747840']
# 0 campaigns were removed, 504 were added

# %%
key = 'google-political-ads-geo-spend.csv'
df_1 = bundle_data_1[key]
df_2 = bundle_data_2[key]

assert list(df_1.columns) == list(df_2.columns)

indexes = ['Country', 'Country_Subdivision_Primary', 'Country_Subdivision_Secondary']
df_1.set_index(indexes, inplace=True)
df_2.set_index(indexes, inplace=True)
ids_1 = set(df_1.index)
ids_2 = set(df_2.index)

assert len(ids_1) == len(df_1) == len(ids_2) == len(df_2)

removed_ids = ids_1 - ids_2
added_ids = ids_2 - ids_1
common_ids = ids_1 & ids_2
assert len(removed_ids) == 0
assert len(added_ids) == 0

for line_id in list(common_ids):
    modifications = df_1.loc[line_id] != df_2.loc[line_id]
    modified_columns = list(modifications[modifications].axes[0])
    if modified_columns:
        print('Line {} has be modified'.format(line_id))
