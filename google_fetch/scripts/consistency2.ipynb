# %%
import tempfile
import zipfile
import datetime
import json
import pathlib
import operator
import collections

import pandas as pd

from google_fetch import config

# %%
def read_bundle(bundle_path):
    fetch_datetime = datetime.datetime.strptime(
        bundle_path.stem,
        'google-political-ads-transparency-bundle_%Y-%m-%d_%H-%M-%S',
    )

    with tempfile.TemporaryDirectory() as tmpdirname:
        tmp_dir = pathlib.Path(tmpdirname)

        with zipfile.ZipFile(bundle_path, "r") as zip_ref:
            zip_ref.extractall(tmpdirname)

            assert set([
                element.name
                for element in tmp_dir.iterdir()
            ]) == {'google-political-ads-transparency-bundle'}

            data_dir = tmp_dir / 'google-political-ads-transparency-bundle'
            assert set([
                element.name
                for element in data_dir.iterdir()
            ]) == {
                'README.txt',
                'google-political-ads-advertiser-stats.csv',
                'google-political-ads-advertiser-weekly-spend.csv',
                'google-political-ads-campaign-targeting.csv',
                'google-political-ads-creative-stats.csv',
                'google-political-ads-geo-spend.csv',
                'google-political-ads-top-keywords-history.csv',
            }

            bundle_data = {}

            with open(data_dir / 'README.txt', 'r') as f:
                bundle_data['README.txt'] = f.read()

            for key in [
                'google-political-ads-advertiser-stats.csv',
                'google-political-ads-advertiser-weekly-spend.csv',
                'google-political-ads-campaign-targeting.csv',
                'google-political-ads-creative-stats.csv',
                'google-political-ads-geo-spend.csv',
                'google-political-ads-top-keywords-history.csv',
            ]:
                bundle_data[key] = pd.read_csv(
                    data_dir / key,
                    dtype=str,
                    keep_default_na=False,
                    na_values={},
                )

    return fetch_datetime, bundle_data

# %%
for bundle_path in sorted(list((config.DATA_DIR / 'google').iterdir())):
    print(bundle_path)
# Out:
# /home/michel/projects/desinfo/political-ads-scraper/data/google/1
# /home/michel/projects/desinfo/political-ads-scraper/data/google/2
# /home/michel/projects/desinfo/political-ads-scraper/data/google/3
# /home/michel/projects/desinfo/political-ads-scraper/data/google/google-political-ads-transparency-bundle_2019-06-14_14-32-03.zip
# /home/michel/projects/desinfo/political-ads-scraper/data/google/google-political-ads-transparency-bundle_2019-06-18_14-18-01.zip
# /home/michel/projects/desinfo/political-ads-scraper/data/google/google-political-ads-transparency-bundle_2019-06-23_14-18-01.zip

# %%
bundle_path_1 = pathlib.Path('/home/michel/projects/desinfo/political-ads-scraper/data/google/google-political-ads-transparency-bundle_2019-06-18_14-18-01.zip')
bundle_path_2 = pathlib.Path('/home/michel/projects/desinfo/political-ads-scraper/data/google/google-political-ads-transparency-bundle_2019-06-23_14-18-01.zip')
fetch_datetime_1, bundle_data_1 = read_bundle(bundle_path_1)
fetch_datetime_2, bundle_data_2 = read_bundle(bundle_path_2)

# %%
bundle_data_1['README.txt'] == bundle_data_2['README.txt']
# Out:
# True

# %% [markdown]
# ## Ads

# %%
key = 'google-political-ads-creative-stats.csv'
df_1 = bundle_data_1[key]
df_2 = bundle_data_2[key]

assert list(df_1.columns) == list(df_2.columns)

# A few ads were run by distinct advertisers, for instance:
# https://transparencyreport.google.com/political-ads/advertiser/AR185084640594231296/creative/CR275167628257918976
# https://transparencyreport.google.com/political-ads/advertiser/AR242125929453715456/creative/CR275167628257918976
duplicate_ad_ids_1 = set([
    ad_id
    for ad_id, count in collections.Counter(df_1['Ad_ID']).items()
    if count > 1
])
duplicate_ad_ids_2 = set([
    ad_id
    for ad_id, count in collections.Counter(df_2['Ad_ID']).items()
    if count > 1
])


common_duplicates = duplicate_ad_ids_1 & duplicate_ad_ids_2
old_duplicates = duplicate_ad_ids_1 - duplicate_ad_ids_2
new_duplicates = duplicate_ad_ids_2 - duplicate_ad_ids_1

print('{} were run by several advertisers (eg {})'.format(len(duplicate_ad_ids_1), list(duplicate_ad_ids_1)[0]))
print('{} are now run by several advertisers (eg {})'.format(len(duplicate_ad_ids_2), list(duplicate_ad_ids_2)[0]))
# Out:
# 367 were run by several advertisers (eg CR109616361486942208)
# 360 are now run by several advertisers (eg CR109616361486942208)

# %%
indexes = ['Ad_ID', 'Advertiser_ID']
df_1.set_index(indexes, inplace=True)
df_2.set_index(indexes, inplace=True)

ids_1 = set(df_1.index)
ids_2 = set(df_2.index)

assert len(ids_1) == len(df_1)
assert len(ids_2) == len(df_2)

removed_ids = ids_1 - ids_2
added_ids = ids_2 - ids_1
common_ids = ids_1 & ids_2
assert len(ids_1) + len(added_ids) - len(removed_ids) == len(ids_2)
assert len(ids_1 | ids_2) == len(common_ids) + len(added_ids) + len(removed_ids)

print('{} ads were removed, {} were added'.format(len(removed_ids), len(added_ids)))
# Out:
# 279 ads were removed, 1339 were added

# %%
removed_ads = []
moved_ads = []

for ad_id, adv_id in removed_ids:
    try:
        new_advertisers = list(df_2.loc[[ad_id]].reset_index()['Advertiser_ID'])
    except KeyError:
        removed_ads.append((ad_id, adv_id))
    else:
        if len(new_advertisers) == 1:
            moved_ads.append((ad_id, adv_id, new_advertisers[0]))
        else:
            print(new_advertisers)

print('{} ads were removed. A few examples:\n'.format(len(removed_ads)))
for ad_id, adv_id in removed_ads[:3]:
    print('{}\n    by {}\n    was removed.\n'.format(
        'https://transparencyreport.google.com/political-ads/advertiser/{}/creative/{}'.format(adv_id, ad_id),
        'https://transparencyreport.google.com/political-ads/advertiser/{}'.format(adv_id),
    ))

print('{} ads changed its advertiser. A few examples:\n'.format(len(moved_ads)))
for ad_id, adv_id, new_adv_id in moved_ads[:3]:
    print('{}\n    by {}\n    was replaced by\n{}\n    by {}\n'.format(
        'https://transparencyreport.google.com/political-ads/advertiser/{}/creative/{}'.format(adv_id, ad_id),
        'https://transparencyreport.google.com/political-ads/advertiser/{}'.format(adv_id),
        'https://transparencyreport.google.com/political-ads/advertiser/{}/creative/{}'.format(new_adv_id, ad_id),
        'https://transparencyreport.google.com/political-ads/advertiser/{}'.format(new_adv_id),
    ))
# Out:
# 214 ads were removed. A few examples:
#
# https://transparencyreport.google.com/political-ads/advertiser/AR242125929453715456/creative/CR179596703182094336
#     by https://transparencyreport.google.com/political-ads/advertiser/AR242125929453715456
#     was removed.
#
# https://transparencyreport.google.com/political-ads/advertiser/AR488306308034854912/creative/CR117534219596464128
#     by https://transparencyreport.google.com/political-ads/advertiser/AR488306308034854912
#     was removed.
#
# https://transparencyreport.google.com/political-ads/advertiser/AR89517838687010816/creative/CR161477026434252800
#     by https://transparencyreport.google.com/political-ads/advertiser/AR89517838687010816
#     was removed.
#
# 65 ads changed its advertiser. A few examples:
#
# https://transparencyreport.google.com/political-ads/advertiser/AR322201712037199872/creative/CR517478000787193856
#     by https://transparencyreport.google.com/political-ads/advertiser/AR322201712037199872
#     was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR464795176020213760/creative/CR517478000787193856
#     by https://transparencyreport.google.com/political-ads/advertiser/AR464795176020213760
#
# https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032/creative/CR372122563595206656
#     by https://transparencyreport.google.com/political-ads/advertiser/AR142057726942380032
#     was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR50464010302128128/creative/CR372122563595206656
#     by https://transparencyreport.google.com/political-ads/advertiser/AR50464010302128128
#
# https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696/creative/CR407128265044525056
#     by https://transparencyreport.google.com/political-ads/advertiser/AR520360095641501696
#     was replaced by
# https://transparencyreport.google.com/political-ads/advertiser/AR338694386453839872/creative/CR407128265044525056
#     by https://transparencyreport.google.com/political-ads/advertiser/AR338694386453839872

# %%
adv_with_removed_ad = set([
    adv_id
    for _, adv_id in removed_ads
])
print(adv_with_removed_ad)
# Out:
# {'AR98551701098725376', 'AR144491221052555264', 'AR374597289391423488', 'AR80178586920681472', 'AR166715924462698496', 'AR140403236820484096', 'AR507835283811598336', 'AR230475229367894016', 'AR210958348219056128', 'AR180201434577371136', 'AR488306308034854912', 'AR419626413717454848', 'AR50338116220747776', 'AR334064892745089024', 'AR94030784163217408', 'AR316331969212317696', 'AR77689292595396608', 'AR89517838687010816', 'AR503512828724903936', 'AR390238117174444032', 'AR400032566754672640', 'AR17917091730423808', 'AR495298652231696384', 'AR60585289713713152', 'AR185084640594231296', 'AR485896728302583808', 'AR119011138590474240', 'AR288284801977286656', 'AR242125929453715456'}

# %% [markdown]
# ## Advertisers

# %%
key = 'google-political-ads-advertiser-stats.csv'
df_1 = bundle_data_1[key]
df_2 = bundle_data_2[key]

assert list(df_1.columns) == list(df_2.columns)

indexes = 'Advertiser_ID'
df_1.set_index(indexes, inplace=True)
df_2.set_index(indexes, inplace=True)
ids_1 = set(df_1.index)
ids_2 = set(df_2.index)

assert len(ids_1) == len(df_1)
assert len(ids_2) == len(df_2)

removed_ids = ids_1 - ids_2
added_ids = ids_2 - ids_1
common_ids = ids_1 & ids_2
assert len(ids_1) + len(added_ids) - len(removed_ids) == len(ids_2)
assert len(ids_1 | ids_2) == len(common_ids) + len(added_ids) + len(removed_ids)

print('{} advertisers were removed, {} were added'.format(len(removed_ids), len(added_ids)))
# Out:
# 12 advertisers were removed, 25 were added

# %%
df_adv_with_removed_ad = df_2.loc[adv_with_removed_ad]
ad_adv_eu = df_adv_with_removed_ad[df_adv_with_removed_ad['Regions'].map(lambda x: 'EU' in x)]
ad_adv_eu
# Out:
#                                                 Advertiser_Name  \
# Advertiser_ID
# AR374597289391423488  KKW Lewica Razem – Razem, Unia Pracy, RSS
# AR166715924462698496     Asociația Platforma Inițiativa România
# AR210958348219056128                  Kansallinen Kokoomus r.p.
# AR50338116220747776     Bündnis 90/Die Grünen Landesverband RLP
# AR316331969212317696  Konfederacja KORWiN Braun Liroy Narodowcy
# AR400032566754672640   Fratelli d'Italia Centrodestra Nazionale
# AR17917091730423808     Bündnis 90/Die Grünen Baden-Württemberg
# AR495298652231696384                        EVOLVEDREAMSOFT SRL
# AR185084640594231296               Sloboda a Solidarita ( SaS )
# AR288284801977286656       Partido Popular Regional De Canarias
# AR242125929453715456                       Sloboda a Solidarita
#
#                      Public_IDs_List                             Regions  \
# Advertiser_ID
# AR374597289391423488                                              EU, PL
# AR166715924462698496                                              EU, RO
# AR210958348219056128                              EE, ES, EU, FI, FR, SE
# AR50338116220747776                                               DE, EU
# AR316331969212317696                                              EU, PL
# AR400032566754672640                                              EU, IT
# AR17917091730423808                                               DE, EU
# AR495298652231696384                                  ES, EU, GB, IT, RO
# AR185084640594231296                                  AT, BE, EU, HU, SK
# AR288284801977286656                                          ES, EU, GB
# AR242125929453715456                  AT, BE, CZ, ES, EU, GB, HU, PL, SK
#
#                           Elections Total_Creatives Spend_USD Spend_EUR  \
# Advertiser_ID
# AR374597289391423488  EU-Parliament              51      4300      3750
# AR166715924462698496  EU-Parliament               8         0        50
# AR210958348219056128  EU-Parliament             193    101600     89400
# AR50338116220747776   EU-Parliament             174      4000      3550
# AR316331969212317696  EU-Parliament              15     46600     41000
# AR400032566754672640  EU-Parliament             271     61700     54300
# AR17917091730423808   EU-Parliament             150      4800      4200
# AR495298652231696384  EU-Parliament             528     21100     18550
# AR185084640594231296  EU-Parliament             936     12500     11000
# AR288284801977286656  EU-Parliament             291      5600      4900
# AR242125929453715456  EU-Parliament             921     40000     35150
#
#                      Spend_INR Spend_BGN Spend_HRK Spend_CZK Spend_DKK  \
# Advertiser_ID
# AR374597289391423488    302000      7425     28200     97000     28500
# AR166715924462698496      3250        75       300      1000       500
# AR210958348219056128   7205500    176825    671700   2325000    674500
# AR50338116220747776     284500      6975     26500     92000     26500
# AR316331969212317696   3303500     81075    308000   1066000    309500
# AR400032566754672640   4374250    107350    407800   1411000    409500
# AR17917091730423808     338500      8300     31600    109000     31500
# AR495298652231696384   1494250     36675    139300    482000    140000
# AR185084640594231296    884750     21700     82500    285000     83000
# AR288284801977286656    393500      9650     36700    127000     37000
# AR242125929453715456   2833750     69525    264100    914000    265500
#
#                      Spend_HUF Spend_PLN Spend_RON Spend_SEK Spend_GBP
# AR474748779908562944                              Future Innovation SRL
# AR50338116220747776             Bündnis 90/Die Grünen Landesverband RLP
# AR201649882778304512                      AfD-Kreisverband Braunschweig
# AR132631338879549440              Lietuvos Respublikos liberalų sąjūdis
# AR242125929453715456                               Sloboda a Solidarita
# AR214800866480226304                         Klassiskt Liberala Partiet
# AR227104401595039744                         FDP Landesverband Saarland
# AR50338116220747776             Bündnis 90/Die Grünen Landesverband RLP
# AR17917091730423808             Bündnis 90/Die Grünen Baden-Württemberg
# AR374597289391423488          KKW Lewica Razem – Razem, Unia Pracy, RSS
# AR374597289391423488          KKW Lewica Razem – Razem, Unia Pracy, RSS
# AR185084640594231296                       Sloboda a Solidarita ( SaS )
# AR237678679797268480                                  Socialdemokratiet
# AR237340030215913472            KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ
# AR474748779908562944                              Future Innovation SRL
# AR242125929453715456                               Sloboda a Solidarita
# AR428206177826897920                     Hrvatska demokratska zajednica
# AR210958348219056128                          Kansallinen Kokoomus r.p.
# AR17917091730423808             Bündnis 90/Die Grünen Baden-Württemberg
# AR271193993235136512                                  SOCIALDEMOKRATIET
# AR283015942256984064                         Venstres Landsorganisation
# AR17917091730423808             Bündnis 90/Die Grünen Baden-Württemberg
# AR73057599863390208                          Liberal Alliance Djursland
# AR400032566754672640           Fratelli d'Italia Centrodestra Nazionale
# AR489541609348661248                                  COALICION CANARIA
# AR486291452976955392                             Avante Comunicación SL
# AR489541609348661248                                  COALICION CANARIA
# AR428206177826897920                     Hrvatska demokratska zajednica
# AR183859784640888832                                   Liberal Alliance
#
#                      Public_IDs_List                             Regions  \
# Advertiser_ID
# AR132631338879549440                                          BG, EU, LT
# AR486291452976955392                                              ES, EU
# AR55967615754960896                                               EU, RO
# AR400032566754672640                                              EU, IT
# AR201649882778304512                                              DE, EU
# AR474748779908562944                              DE, ES, EU, GB, IT, RO
# AR288284801977286656                                          ES, EU, GB
# AR474748779908562944                              DE, ES, EU, GB, IT, RO
# AR73057599863390208                                               DK, EU
# AR227104401595039744                                              DE, EU
# AR507019171305881600                                              EU, GR
# AR227104401595039744                                              DE, EU
# AR362903983230025728                                              DK, EU
# AR185084640594231296                                  AT, BE, EU, HU, SK
# AR489541609348661248                  DE, ES, EU, FR, IT, PL, PT, SE, SK
# AR210958348219056128                              EE, ES, EU, FI, FR, SE
# AR210958348219056128                              EE, ES, EU, FI, FR, SE
# AR522320249995919360                                              CZ, EU
# AR214800866480226304                                              EU, SE
# AR242125929453715456                  AT, BE, CZ, ES, EU, GB, HU, PL, SK
# AR214800866480226304                                              EU, SE
# AR214800866480226304                                              EU, SE
# AR400032566754672640                                              EU, IT
# AR132631338879549440                                          BG, EU, LT
# AR166715924462698496                                              EU, RO
# AR17917091730423808                                               DE, EU
# AR478461555797655552                                              ES, EU
# AR400032566754672640                                              EU, IT
# AR362903983230025728                                              DK, EU
# AR50338116220747776                                               DE, EU
# ...                              ...                                 ...
# AR316331969212317696                                              EU, PL
# AR474748779908562944                              DE, ES, EU, GB, IT, RO
# AR50338116220747776                                               DE, EU
# AR201649882778304512                                              DE, EU
# AR132631338879549440                                          BG, EU, LT
# AR242125929453715456                  AT, BE, CZ, ES, EU, GB, HU, PL, SK
# AR214800866480226304                                              EU, SE
# AR227104401595039744                                              DE, EU
# AR50338116220747776                                               DE, EU
# AR17917091730423808                                               DE, EU
# AR374597289391423488                                              EU, PL
# AR374597289391423488                                              EU, PL
# AR185084640594231296                                  AT, BE, EU, HU, SK
# AR237678679797268480                                              DK, EU
# AR237340030215913472                                          DE, EU, PL
# AR474748779908562944                              DE, ES, EU, GB, IT, RO
# AR242125929453715456                  AT, BE, CZ, ES, EU, GB, HU, PL, SK
# AR428206177826897920                                              EU, HR
# AR210958348219056128                              EE, ES, EU, FI, FR, SE
# AR17917091730423808                                               DE, EU
# AR271193993235136512                                              DK, EU
# AR283015942256984064                                          DK, EU, GR
# AR17917091730423808                                               DE, EU
# AR73057599863390208                                               DK, EU
# AR400032566754672640                                              EU, IT
# AR489541609348661248                  DE, ES, EU, FR, IT, PL, PT, SE, SK
# AR486291452976955392                                              ES, EU
# AR489541609348661248                  DE, ES, EU, FR, IT, PL, PT, SE, SK
# AR428206177826897920                                              EU, HR
# AR183859784640888832                                          DE, DK, EU
#
#                           Elections Total_Creatives Spend_USD Spend_EUR  \
# Advertiser_ID
# AR132631338879549440  EU-Parliament             264      8800      7750
# AR486291452976955392  EU-Parliament              67      2200      1950
# AR55967615754960896   EU-Parliament             105      9400      8300
# AR400032566754672640  EU-Parliament             271     61700     54300
# AR201649882778304512  EU-Parliament              15       200       150
# AR474748779908562944  EU-Parliament              99    164200    144500
# AR288284801977286656  EU-Parliament             291      5600      4900
# AR474748779908562944  EU-Parliament              99    164200    144500
# AR73057599863390208   EU-Parliament             144      5400      4700
# AR227104401595039744  EU-Parliament              60     11400     10050
# AR507019171305881600  EU-Parliament              33       500       450
# AR227104401595039744  EU-Parliament              60     11400     10050
# AR362903983230025728  EU-Parliament              18       300       250
# AR185084640594231296  EU-Parliament             936     12500     11000
# AR489541609348661248  EU-Parliament            5459     20300     17900
# AR210958348219056128  EU-Parliament             193    101600     89400
# AR210958348219056128  EU-Parliament             193    101600     89400
# AR522320249995919360  EU-Parliament             235      1700      1550
# AR214800866480226304  EU-Parliament               6      1300      1150
# AR242125929453715456  EU-Parliament             921     40000     35150
# AR214800866480226304  EU-Parliament               6      1300      1150
# AR214800866480226304  EU-Parliament               6      1300      1150
# AR400032566754672640  EU-Parliament             271     61700     54300
# AR132631338879549440  EU-Parliament             264      8800      7750
# AR166715924462698496  EU-Parliament               8         0        50
# AR17917091730423808   EU-Parliament             150      4800      4200
# AR478461555797655552  EU-Parliament              62      4400      3900
# AR400032566754672640  EU-Parliament             271     61700     54300
# AR362903983230025728  EU-Parliament              18       300       250
# AR50338116220747776   EU-Parliament             174      4000      3550
# ...                             ...             ...       ...       ...
# AR316331969212317696  EU-Parliament              15     46600     41000
# AR474748779908562944  EU-Parliament              99    164200    144500
# AR50338116220747776   EU-Parliament             174      4000      3550
# AR400032566754672640  17557500    235700    260925    571500     46900
# AR362903983230025728     75000      1100      1200      2250       200
# AR50338116220747776    1140000     15300     16950     37500      3050
# ...                        ...       ...       ...       ...       ...
# AR316331969212317696  13260000    178000    197100    432000     35400
# AR474748779908562944  46740000    627300    694575   1522500    124800
# AR50338116220747776    1140000     15300     16950     37500      3050
# AR201649882778304512     52500       700       825      1500       150
# AR132631338879549440   2512500     33700     37350     81750      6700
# AR242125929453715456  11377500    152700    169050    370500     30350
# AR214800866480226304    375000      5000      5550     12000      1000
# AR227104401595039744   3247500     43600     48300    105750      8700
# AR50338116220747776    1140000     15300     16950     37500      3050
# AR17917091730423808    1357500     18200     20175     44250      3650
# AR374597289391423488   1215000     16300     18000     39750      3250
# AR374597289391423488   1215000     16300     18000     39750      3250
# AR185084640594231296   3555000     47700     52800    115500      9500
# AR237678679797268480   6307500     84700     93750    205500     16850
# AR237340030215913472  36375000    488100    540525   1184250     97100
# AR474748779908562944  46740000    627300    694575   1522500    124800
# AR242125929453715456  11377500    152700    169050    370500     30350
# AR428206177826897920   6645000     89200     98700    216000     17750
# AR210958348219056128  28927500    388200    429825    942000     77250
# AR17917091730423808    1357500     18200     20175     44250      3650
# AR271193993235136512  73972500    992700   1099200   2409000    197500
# AR283015942256984064  44205000    593200    656925   1439250    118050
# AR17917091730423808    1357500     18200     20175     44250      3650
# AR73057599863390208    1530000     20500     22650     49500      4100
# AR400032566754672640  17557500    235700    260925    571500     46900
# AR489541609348661248   5790000     77700     86025    188250     15450
# AR486291452976955392    630000      8400      9375     20250      1700
# AR489541609348661248   5790000     77700     86025    188250     15450
# AR428206177826897920   6645000     89200     98700    216000     17750
# AR183859784640888832  13185000    177000    195975    429750     35200
#
# [78 rows x 17 columns]

# %% [markdown]
# ## Advertisers weekly spends

# %%
key = 'google-political-ads-advertiser-weekly-spend.csv'
df_1 = bundle_data_1[key]
df_2 = bundle_data_2[key]

assert list(df_1.columns) == list(df_2.columns)

indexes = ['Advertiser_ID', 'Week_Start_Date']
df_1.set_index(indexes, inplace=True)
df_2.set_index(indexes, inplace=True)

ids_1 = set(df_1.index)
ids_2 = set(df_2.index)

assert len(ids_1) == len(df_1)
assert len(ids_2) == len(df_2)

removed_ids = ids_1 - ids_2
added_ids = ids_2 - ids_1
common_ids = ids_1 & ids_2
assert len(ids_1) + len(added_ids) - len(removed_ids) == len(ids_2)
assert len(ids_1 | ids_2) == len(common_ids) + len(added_ids) + len(removed_ids)

print('{} lines were removed, {} were added'.format(len(removed_ids), len(added_ids)))

old_advertisers = set(map(operator.itemgetter(0), removed_ids))
new_advertisers = set(map(operator.itemgetter(0), added_ids))

assert not old_advertisers & new_advertisers

print('Lines have been removed about the following advertisers:\n')
for advertiser_id in old_advertisers:
    print('{} ({})\n'.format(
        'https://transparencyreport.google.com/political-ads/advertiser/{}'.format(advertiser_id),
        [
            removed_id[1]
            for removed_id in removed_ids
            if removed_id[0] == advertiser_id
        ]
    ))

print('Lines have been added about the following advertisers:\n')
for advertiser_id in new_advertisers:
    print('{} ({})\n'.format(
        'https://transparencyreport.google.com/political-ads/advertiser/{}'.format(advertiser_id),
        [
            added_id[1]
            for added_id in added_ids
            if added_id[0] == advertiser_id
        ]
    ))

for line_id in list(common_ids):
    modifications = df_1.loc[line_id] != df_2.loc[line_id]
    modified_columns = list(modifications[modifications].axes[0])
    if modified_columns:
        print('Line {} has be modified'.format(line_id))
# Out:
# 72 lines were removed, 251 were added
# Lines have been removed about the following advertisers:
#
# https://transparencyreport.google.com/political-ads/advertiser/AR340216110546681856 (['2018-06-24', '2018-10-21', '2018-09-30', '2018-09-09', '2019-04-21', '2018-08-05', '2018-07-01', '2018-09-16', '2018-07-22', '2018-05-27', '2018-07-08', '2018-09-02', '2018-08-26', '2019-04-28', '2018-08-12', '2018-10-14', '2018-06-03', '2018-09-23', '2018-10-28', '2018-08-19', '2018-06-17', '2018-06-10', '2018-07-15', '2018-10-07', '2018-07-29'])
#
# https://transparencyreport.google.com/political-ads/advertiser/A
(['2019-06-09'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR83562883710976 (['2019-06-09'])
#
# https://transparencyreport.google.com/political-ads/advertiser/AR481432711093813248 (['2019-06-09'])
#
# Line ('AR132631338879549440', '2019-03-31') has be modified
# Line ('AR488306308034854912', '2019-02-17') has be modified
# Line ('AR98551701098725376', '2019-05-05') has be modified
# Line ('AR119011138590474240', '2018-08-12') has be modified
# Line ('AR486291452976955392', '2019-05-12') has be modified
# Line ('AR119011138590474240', '2018-08-05') has be modified
# Line ('AR81539232560054272', '2019-05-05') has be modified
# Line ('AR419626413717454848', '2018-09-30') has be modified
# Line ('AR383080296477622272', '2019-06-02') has be modified
# Line ('AR55967615754960896', '2019-05-19') has be modified
# Line ('AR400032566754672640', '2019-05-12') has be modified
# Line ('AR201649882778304512', '2019-05-12') has be modified
# Line ('AR519831505426448384', '2018-10-28') has be modified
# Line ('AR474748779908562944', '2019-05-12') has be modified
# Line ('AR77689292595396608', '2018-10-28') has be modified
# Line ('AR81539232560054272', '2019-04-28') has be modified
# Line ('AR140403236820484096', '2019-05-26') has be modified
# Line ('AR6195198266703872', '2019-05-26') has be modified
# Line ('AR240608328529477632', '2018-09-23') has be modified
# Line ('AR488306308034854912', '2019-05-05') has be modified
# Line ('AR383251270535741440', '2019-03-03') has be modified
# Line ('AR488306308034854912', '2019-02-10') has be modified
# Line ('AR399188966458261504', '2019-05-05') has be modified
# Line ('AR485896728302583808', '2019-05-19') has be modified
# Line ('AR288284801977286656', '2019-05-19') has be modified
# Line ('AR140403236820484096', '2019-04-14') has be modified
# Line ('AR474748779908562944', '2019-04-14') has be modified
# Line ('AR98551701098725376', '2019-05-26') has be modified
# Line ('AR73057599863390208', '2019-05-26') has be modified
# Line ('AR227104401595039744', '2019-05-26') has be modified
# Line ('AR288179248861020160', '2019-04-07') has be modified
# Line ('AR94030784163217408', '2019-03-17') has be modified
# Line ('AR373464517536907264', '2019-03-10') has be modified
# Line ('AR507019171305881600', '2019-05-19') has be modified
# Line ('AR227104401595039744', '2019-05-19') has be modified
# Line ('AR94030784163217408', '2018-07-29') has be modified
# Line ('AR383251270535741440', '2019-02-17') has be modified
# Line ('AR6195198266703872', '2019-03-31') has be modified
# Line ('AR488306308034854912', '2019-06-02') has be modified
# Line ('AR390238117174444032', '2019-04-28') has be modified
# Line ('AR362903983230025728', '2019-05-26') has be modified
# Line ('AR488306308034854912', '2019-03-10') has be modified
# Line ('AR485896728302583808', '2019-05-05') has be modified
# Line ('AR185084640594231296', '2019-05-05') has be modified
# Line ('AR519831505426448384', '2018-10-07') has be modified
# Line ('AR240608328529477632', '2018-08-26') has be modified
# Line ('AR140403236820484096', '2019-04-28') has be modified
# Line ('AR352083414423175168', '2018-10-14') has be modified
# Line ('AR89517838687010816', '2018-11-04') has be modified
# Line ('AR120847323008860160', '2019-06-02') has be modified
# Line ('AR375716317350592512', '2019-05-26') has be modified
# Line ('AR60189740405620736', '2019-06-02') has be modified
# Line ('AR373464517536907264', '2019-03-17') has be modified
# Line ('AR89517838687010816', '2018-10-21') has be modified
# Line ('AR144491221052555264', '2018-11-04') has be modified
# Line ('AR390238117174444032', '2019-04-21') has be modified
# Line ('AR191840040035287040', '2019-05-26') has be modified
# Line ('AR489541609348661248', '2019-05-12') has be modified
# Line ('AR140403236820484096', '2019-03-17') has be modified
# Line ('AR210958348219056128', '2019-05-19') has be modified
# Line ('AR94030784163217408', '2019-06-02') has be modified
# Line ('AR40198145111490560', '2018-10-28') has be modified
# Line ('AR383251270535741440', '2019-05-12') has be modified
# Line ('AR375716317350592512', '2019-06-02') has be modified
# Line ('AR210958348219056128', '2019-05-05') has be modified
# Line ('AR522320249995919360', '2019-04-28') has be modified
# Line ('AR121262938404159488', '2019-06-02') has be modified
# Line ('AR94030784163217408', '2019-03-03') has be modified
# Line ('AR214800866480226304', '2019-05-19') has be modified
# Line ('AR334064892745089024', '2019-06-02') has be modified
# Line ('AR89517838687010816', '2018-10-14') has be modified
# Line ('AR216489716340490240', '2019-04-28') has be modified
# Line ('AR242125929453715456', '2019-05-12') has be modified
# Line ('AR485896728302583808', '2019-06-02') has be modified
# Line ('AR214800866480226304', '2019-04-28') has be modified
# Line ('AR144491221052555264', '2018-09-16') has be modified
# Line ('AR214800866480226304', '2019-05-12') has be modified
# Line ('AR383251270535741440', '2019-03-17') has be modified
# Line ('AR383251270535741440', '2019-03-10') has be modified
# Line ('AR400032566754672640', '2019-04-28') has be modified
# Line ('AR132631338879549440', '2019-04-07') has be modified
# Line ('AR288179248861020160', '2019-04-21') has be modified
# Line ('AR390238117174444032', '2019-05-05') has be modified
# Line ('AR119011138590474240', '2018-07-29') has be modified
# Line ('AR191840040035287040', '2019-06-02') has be modified
# Line ('AR166715924462698496', '2019-05-19') has be modified
# Line ('AR200379397092409344', '2019-06-02') has be modified
# Line ('AR315375668974059520', '2019-01-27') has be modified
# Line ('AR488306308034854912', '2019-04-14') has be modified
# Line ('AR77689292595396608', '2018-10-21') has be modified
# Line ('AR140403236820484096', '2019-05-05') has be modified
# Line ('AR488306308034854912', '2019-03-24') has be modified
# Line ('AR94030784163217408', '2019-05-19') has be modified
# Line ('AR140403236820484096', '2019-06-02') has be modified
# Line ('AR180201434577371136', '2019-05-26') has be modified
# Line ('AR17917091730423808', '2019-04-28') has be modified
# Line ('AR478461555797655552', '2019-05-12') has be modified
# Line ('AR6195198266703872', '2019-05-19') has be modified
# Line ('AR485896728302583808', '2019-04-21') has be modified
# Line ('AR432363981047332864', '2019-06-02') has be modified
# Line ('AR400032566754672640', '2019-04-21') has be modified
# Line ('AR362903983230025728', '2019-06-02') has be modified
# Line ('AR334064892745089024', '2019-05-19') has be modified
# Line ('AR60585289713713152', '2018-11-04') has be modified
# Line ('AR119011138590474240', '2018-08-19') has be modified
# Line ('AR140403236820484096', '2019-03-31') has be modified
# Line ('AR50338116220747776', '2019-04-28') has be modified
# Line ('AR210958348219056128', '2019-05-12') has be modified
# Line ('AR94030784163217408', '2019-04-14') has be modified
# Line ('AR530356305605427200', '2019-05-19') has be modified
# Line ('AR94030784163217408', '2019-05-26') has be modified
# Line ('AR240608328529477632', '2018-07-01') has be modified
# Line ('AR383251270535741440', '2019-05-05') has be modified
# Line ('AR383251270535741440', '2019-04-21') has be modified
# Line ('AR210958348219056128', '2019-04-07') has be modified
# Line ('AR40198145111490560', '2018-10-21') has be modified
# Line ('AR132631338879549440', '2019-03-24') has be modified
# Line ('AR94030784163217408', '2018-08-05') has be modified
# Line ('AR175306133932605440', '2019-06-02') has be modified
# Line ('AR40198145111490560', '2018-11-04') has be modified
# Line ('AR474748779908562944', '2019-05-05') has be modified
# Line ('AR77689292595396608', '2018-11-04') has be modified
# Line ('AR94030784163217408', '2018-07-22') has be modified
# Line ('AR383251270535741440', '2019-04-28') has be modified
# Line ('AR240608328529477632', '2018-09-02') has be modified
# Line ('AR383251270535741440', '2019-02-24') has be modified
# Line ('AR217815727363588096', '2019-06-02') has be modified
# Line ('AR503512828724903936', '2019-05-19') has be modified
# Line ('AR495298652231696384', '2019-05-19') has be modified
# Line ('AR6195198266703872', '2019-01-27') has be modified
# Line ('AR288179248861020160', '2019-04-28') has be modified
# Line ('AR419626413717454848', '2018-10-07') has be modified
# Line ('AR98551701098725376', '2019-06-02') has be modified
# Line ('AR428206177826897920', '2019-05-05') has be modified
# Line ('AR522320249995919360', '2019-05-12') has be modified
# Line ('AR120847323008860160', '2019-04-28') has be modified
# Line ('AR240608328529477632', '2018-09-30') has be modified
# Line ('AR478461555797655552', '2019-05-19') has be modified
# Line ('AR488306308034854912', '2019-05-12') has be modified
# Line ('AR32708546780987392', '2019-05-19') has be modified
# Line ('AR240608328529477632', '2018-10-07') has be modified
# Line ('AR152882144039927808', '2019-06-02') has be modified
# Line ('AR488306308034854912', '2019-04-07') has be modified
# Line ('AR488306308034854912', '2019-02-24') has be modified
# Line ('AR205658702173175808', '2019-06-02') has be modified
# Line ('AR17917091730423808', '2019-05-26') has be modified
# Line ('AR519831505426448384', '2018-10-14') has be modified
# Line ('AR240608328529477632', '2018-10-14') has be modified
# Line ('AR144491221052555264', '2018-10-28') has be modified
# Line ('AR240608328529477632', '2018-07-08') has be modified
# Line ('AR144491221052555264', '2018-10-21') has be modified
# Line ('AR383251270535741440', '2019-02-10') has be modified
# Line ('AR519831505426448384', '2018-10-21') has be modified
# Line ('AR6195198266703872', '2019-04-07') has be modified
# Line ('AR362903983230025728', '2019-05-19') has be modified
# Line ('AR400032566754672640', '2019-05-05') has be modified
# Line ('AR144491221052555264', '2018-09-30') has be modified
# Line ('AR217815727363588096', '2019-05-26') has be modified
# Line ('AR488306308034854912', '2019-04-21') has be modified
# Line ('AR400032566754672640', '2019-04-14') has be modified
# Line ('AR488306308034854912', '2019-05-26') has be modified
# Line ('AR100996740080992256', '2019-06-02') has be modified
# Line ('AR474748779908562944', '2019-04-28') has be modified
# Line ('AR488306308034854912', '2019-03-03') has be modified
# Line ('AR485896728302583808', '2019-04-28') has be modified
# Line ('AR230475229367894016', '2018-10-28') has be modified
# Line ('AR80178586920681472', '2019-05-19') has be modified
# Line ('AR288179248861020160', '2019-03-31') has be modified
# Line ('AR75218140211970048', '2019-06-02') has be modified
# Line ('AR488306308034854912', '2019-02-03') has be modified
# Line ('AR562822410072489984', '2019-06-02') has be modified
# Line ('AR198061076825243648', '2019-06-02') has be modified
# Line ('AR119011138590474240', '2018-07-15') has be modified
# Line ('AR311843487869829120', '2019-06-02') has be modified
# Line ('AR532605081762136064', '2019-06-02') has be modified
# Line ('AR530356305605427200', '2019-05-12') has be modified
# Line ('AR6195198266703872', '2019-04-28') has be modified
# Line ('AR77689292595396608', '2018-10-14') has be modified
# Line ('AR352083414423175168', '2018-09-30') has be modified
# Line ('AR120847323008860160', '2019-04-21') has be modified
# Line ('AR157291735423123456', '2019-06-02') has be modified
# Line ('AR316331969212317696', '2019-05-19') has be modified
# Line ('AR474748779908562944', '2019-05-19') has be modified
# Line ('AR6195198266703872', '2019-04-14') has be modified
# Line ('AR50710026028843008', '2019-06-02') has be modified
# Line ('AR503512828724903936', '2019-05-26') has be modified
# Line ('AR50338116220747776', '2019-05-19') has be modified
# Line ('AR13000625486823424', '2019-06-02') has be modified
# Line ('AR201649882778304512', '2019-05-19') has be modified
# Line ('AR140403236820484096', '2019-05-19') has be modified
# Line ('AR132631338879549440', '2019-03-17') has be modified
# Line ('AR94030784163217408', '2019-03-10') has be modified
# Line ('AR220642022002786304', '2019-06-02') has be modified
# Line ('AR89517838687010816', '2018-10-07') has be modified
# Line ('AR383251270535741440', '2019-04-07') has be modified
# Line ('AR352083414423175168', '2018-10-07') has be modified
# Line ('AR240608328529477632', '2018-08-19') has be modified
# Line ('AR77689292595396608', '2018-10-07') has be modified
# Line ('AR503512828724903936', '2019-06-02') has be modified
# Line ('AR300281023592136704', '2019-06-02') has be modified
# Line ('AR383251270535741440', '2019-02-03') has be modified
# Line ('AR81539232560054272', '2019-04-21') has be modified
# Line ('AR242125929453715456', '2019-05-05') has be modified
# Line ('AR214800866480226304', '2019-05-05') has be modified
# Line ('AR485896728302583808', '2019-05-26') has be modified
# Line ('AR230475229367894016', '2018-11-04') has be modified
# Line ('AR373464517536907264', '2019-06-02') has be modified
# Line ('AR376667944664432640', '2019-06-02') has be modified
# Line ('AR140403236820484096', '2019-03-24') has be modified
# Line ('AR77689292595396608', '2018-09-23') has be modified
# Line ('AR352083414423175168', '2018-10-28') has be modified
# Line ('AR315375668974059520', '2019-01-20') has be modified
# Line ('AR98551701098725376', '2019-05-12') has be modified
# Line ('AR475747136466583552', '2019-04-14') has be modified
# Line ('AR227104401595039744', '2019-05-12') has be modified
# Line ('AR50338116220747776', '2019-05-12') has be modified
# Line ('AR89517838687010816', '2018-09-23') has be modified
# Line ('AR17917091730423808', '2019-05-05') has be modified
# Line ('AR240608328529477632', '2018-09-16') has be modified
# Line ('AR334064892745089024', '2019-05-05') has be modified
# Line ('AR77689292595396608', '2018-09-30') has be modified
# Line ('AR288179248861020160', '2019-05-12') has be modified
# Line ('AR350209296853630976', '2019-06-02') has be modified
# Line ('AR374597289391423488', '2019-05-12') has be modified
# Line ('AR419626413717454848', '2018-10-21') has be modified
# Line ('AR6195198266703872', '2019-04-21') has be modified
# Line ('AR513786390496935936', '2019-06-02') has be modified
# Line ('AR140403236820484096', '2019-04-21') has be modified
# Line ('AR519831505426448384', '2018-11-04') has be modified
# Line ('AR374597289391423488', '2019-05-19') has be modified
# Line ('AR185084640594231296', '2019-04-28') has be modified
# Line ('AR488306308034854912', '2019-03-31') has be modified
# Line ('AR503512828724903936', '2019-05-12') has be modified
# Line ('AR98551701098725376', '2019-04-14') has be modified
# Line ('AR383251270535741440', '2019-03-24') has be modified
# Line ('AR350471805254762496', '2019-06-02') has be modified
# Line ('AR352083414423175168', '2018-10-21') has be modified
# Line ('AR383251270535741440', '2019-03-31') has be modified
# Line ('AR237678679797268480', '2019-06-02') has be modified
# Line ('AR94030784163217408', '2019-04-28') has be modified
# Line ('AR230475229367894016', '2018-10-21') has be modified
# Line ('AR237340030215913472', '2019-05-19') has be modified
# Line ('AR94030784163217408', '2019-02-17') has be modified
# Line ('AR474748779908562944', '2019-04-21') has be modified
# Line ('AR488306308034854912', '2019-05-19') has be modified
# Line ('AR334064892745089024', '2019-05-26') has be modified
# Line ('AR144491221052555264', '2018-10-14') has be modified
# Line ('AR242125929453715456', '2019-05-19') has be modified
# Line ('AR374590417443749888', '2019-06-02') has be modified
# Line ('AR94030784163217408', '2019-04-07') has be modified
# Line ('AR40198145111490560', '2018-10-14') has be modified
# Line ('AR240608328529477632', '2018-09-09') has be modified
# Line ('AR288179248861020160', '2019-05-05') has be modified
# Line ('AR144491221052555264', '2018-09-23') has be modified
# Line ('AR488306308034854912', '2019-04-28') has be modified
# Line ('AR428206177826897920', '2019-05-19') has be modified
# Line ('AR210958348219056128', '2019-05-26') has be modified
# Line ('AR334064892745089024', '2019-05-12') has be modified
# Line ('AR17917091730423808', '2019-05-12') has be modified
# Line ('AR271193993235136512', '2019-06-02') has be modified
# Line ('AR288179248861020160', '2019-04-14') has be modified
# Line ('AR89517838687010816', '2018-09-30') has be modified
# Line ('AR180201434577371136', '2019-06-02') has be modified
# Line ('AR140403236820484096', '2019-04-07') has be modified
# Line ('AR98551701098725376', '2019-04-21') has be modified
# Line ('AR283015942256984064', '2019-06-02') has be modified
# Line ('AR240608328529477632', '2018-08-05') has be modified
# Line ('AR80178586920681472', '2019-05-12') has be modified
# Line ('AR89517838687010816', '2018-10-28') has be modified
# Line ('AR17917091730423808', '2019-05-19') has be modified
# Line ('AR119011138590474240', '2018-07-22') has be modified
# Line ('AR488306308034854912', '2019-03-17') has be modified
# Line ('AR399188966458261504', '2019-05-12') has be modified
# Line ('AR73057599863390208', '2019-06-02') has be modified
# Line ('AR98551701098725376', '2019-05-19') has be modified
# Line ('AR194446432348930048', '2018-10-07') has be modified
# Line ('AR400032566754672640', '2019-05-19') has be modified
# Line ('AR489541609348661248', '2019-05-19') has be modified
# Line ('AR486291452976955392', '2019-05-19') has be modified
# Line ('AR485896728302583808', '2019-05-12') has be modified
# Line ('AR119011138590474240', '2018-07-01') has be modified
# Line ('AR98551701098725376', '2019-04-28') has be modified
# Line ('AR6195198266703872', '2019-05-05') has be modified
# Line ('AR194446432348930048', '2018-09-30') has be modified
# Line ('AR6195198266703872', '2019-06-02') has be modified
# Line ('AR288179248861020160', '2019-03-24') has be modified
# Line ('AR489541609348661248', '2019-05-05') has be modified
# Line ('AR94030784163217408', '2019-05-12') has be modified
# Line ('AR98551701098725376', '2019-02-03') has be modified
# Line ('AR140403236820484096', '2019-05-12') has be modified
# Line ('AR428206177826897920', '2019-05-12') has be modified
# Line ('AR183859784640888832', '2019-06-02') has be modified
# Line ('AR383251270535741440', '2019-04-14') has be modified

# %% [markdown]
# ## Campaigns

# %%
key = 'google-political-ads-campaign-targeting.csv'
df_1 = bundle_data_1[key]
df_2 = bundle_data_2[key]
assert list(df_1.columns) == list(df_2.columns)

duplicate_campaign_ids_1 = [
    campaign_id
    for campaign_id, count in collections.Counter(df_1['Campaign_ID']).items()
    if count > 1
]
duplicate_campaign_ids_2 = [
    campaign_id
    for campaign_id, count in collections.Counter(df_2['Campaign_ID']).items()
    if count > 1
]
assert set(duplicate_campaign_ids_1) == set(duplicate_campaign_ids_2)

print('The following campaigns were run by several advertisers: {}'.format(duplicate_campaign_ids_1))

indexes = ['Campaign_ID', 'Advertiser_ID']
df_1.set_index(indexes, inplace=True)
df_2.set_index(indexes, inplace=True)

ids_1 = set(df_1.index)
ids_2 = set(df_2.index)

assert len(ids_1) == len(df_1)
assert len(ids_2) == len(df_2)

removed_ids = ids_1 - ids_2
added_ids = ids_2 - ids_1
common_ids = ids_1 & ids_2
assert len(ids_1) + len(added_ids) - len(removed_ids) == len(ids_2)
assert len(ids_1 | ids_2) == len(common_ids) + len(added_ids) + len(removed_ids)

print('{} campaigns were removed, {} were added'.format(len(removed_ids), len(added_ids)))

print('Removed campaigns: {}'.format(removed_ids))
# Campaign data can change. For example, End_Date or Gender_Targeting...
# Out:
# The following campaigns were run by several advertisers: ['CA102091303906443264', 'CA12561095713619968', 'CA129676676257808384', 'CA138683050878828544', 'CA168796475340357632', 'CA172438882485272576', 'CA186731709012639744', 'CA190399679802900480', 'CA20351410474319872', 'CA22429487450816512', 'CA239086054680821760', 'CA246748276336885760', 'CA267875667142508544', 'CA271464473095569408', 'CA274551901746364416', 'CA288141865465675776', 'CA288878538256285696', 'CA294897264906731520', 'CA301024568330420224', 'CA304169171585859584', 'CA311790161555881984', 'CA327975797350465536', 'CA328327641071353856', 'CA329242434745663488', 'CA345004208807739392', 'CA346688660621492224', 'CA34819609106317312', 'CA360199459503603712', 'CA360410565736136704', 'CA362455657363800064', 'CA364703059130974208', 'CA364876781968162816', 'CA366002681875005440', 'CA370034316136153088', 'CA373710258385715200', 'CA376226765623787520', 'CA388611664599056384', 'CA392461329685807104', 'CA399779679080284160', 'CA412255562642751488', 'CA418399633618763776', 'CA418746254659420160', 'CA419573912037228544', 'CA430005253727846400', 'CA474126456327241728', 'CA482533322233217024', 'CA487690856401207296', 'CA490803848697348096', 'CA495791233440940032', 'CA50187758005649408', 'CA508818247206830080', 'CA512460654351745024', 'CA51567370220601344', 'CA526832645716312064', 'CA549615351277551616', 'CA552170616300503040', 'CA565113242548961280', 'CA570663577245974528', 'CA66604291242065920', 'CA67808531352387584', 'CA71107890869436416', 'CA72796740729700352', 'CA78645317955747840']
# 43 campaigns were removed, 178 were added
# Removed campaigns: {('CA246904681865936896', 'AR89517838687010816'), ('CA144539599564177408', 'AR88014531413934080'), ('CA508113460253425664', 'AR89517838687010816'), ('CA548878403609034752', 'AR88014531413934080'), ('CA87736080094199808', 'AR160072125451862016'), ('CA332796880960356352', 'AR412273704584609792'), ('CA491374220354256896', 'AR374597289391423488'), ('CA295757632755466240', 'AR88014531413934080'), ('CA108779358260297728', 'AR374597289391423488'), ('CA501862736649519104', 'AR89517838687010816'), ('CA40659390239342592', 'AR322201712037199872'), ('CA198490985871704064', 'AR89517838687010816'), ('CA475593204838694912', 'AR565396091915206656'), ('CA510514518770581504', 'AR374597289391423488'), ('CA302504510981406720', 'AR142057726942380032'), ('CA27362721246740480', 'AR374597289391423488'), ('CA256616668074082304', 'AR340216110546681856'), ('CA278294639327313920', 'AR142057726942380032'), ('CA566660255409242112', 'AR70000132904452096'), ('CA78831410298748928', 'AR142057726942380032'), ('CA559232779485708288', 'AR180201434577371136'), ('CA274357013310341120', 'AR374597289391423488'), ('CA137271277948764160', 'AR17917091730423808'), ('CA290116588349161472', 'AR322201712037199872'), ('CA124620846915387392', 'AR520360095641501696'), ('CA444999018917920768', 'AR124043328432898048'), ('CA135440591088517120', 'AR89517838687010816'), ('CA193472265046720512', 'AR88014531413934080'), ('CA274849594519584768', 'AR374597289391423488'), ('CA46925232128131072', 'AR374597289391423488'), ('CA515144287357239296', 'AR520360095641501696'), ('CA234519782890668032', 'AR89517838687010816'), ('CA561161597758734336', 'AR565396091915206656'), ('CA95906551000203264', 'AR178086523961344000'), ('CA509107143887028224', 'AR374597289391423488'), ('CA199616885778546688', 'AR89517838687010816'), ('CA395531990784278528', 'AR374597289391423488'), ('CA18136994055979008', 'AR340216110546681856'), ('CA380383194454687744', 'AR556388892660465664'), ('CA264919080375418880', 'AR89517838687010816'), ('CA348323084656181248', 'AR88014531413934080'), ('CA485463245843333120', 'AR374597289391423488'), ('CA165407780503552000', 'AR565396091915206656')}

# %% [markdown]
# ## Total spending

# %%
key = 'google-political-ads-geo-spend.csv'
df_1 = bundle_data_1[key]
df_2 = bundle_data_2[key]

assert list(df_1.columns) == list(df_2.columns)

indexes = ['Country', 'Country_Subdivision_Primary', 'Country_Subdivision_Secondary']
df_1.set_index(indexes, inplace=True)
df_2.set_index(indexes, inplace=True)
ids_1 = set(df_1.index)
ids_2 = set(df_2.index)

assert len(ids_1) == len(df_1) == len(ids_2) == len(df_2)

removed_ids = ids_1 - ids_2
added_ids = ids_2 - ids_1
common_ids = ids_1 & ids_2
assert len(removed_ids) == 0
assert len(added_ids) == 0

for line_id in list(common_ids):
    suspicious_modifications = df_1.loc[line_id].map(int) > df_2.loc[line_id].map(int)
    modified_columns = list(suspicious_modifications[suspicious_modifications].axes[0])
    if modified_columns:
        print('Line {} has be modified'.format(line_id))
# Out:
# Line ('US', 'US-PA', 'PA-14') has be modified
# Line ('US', 'US-PA', 'PA-11') has be modified
# Line ('US', 'US-PA', 'PA-2') has be modified
# Line ('US', 'US-PA', 'PA-13') has be modified
# Line ('PL', '', '') has be modified
# Line ('US', 'US-PA', 'PA-15') has be modified
# Line ('US', 'US-NC', 'NC-4') has be modified

# %%
line_id = ('PL', '', '')
df_1.loc[line_id]['Spend_EUR'], df_2.loc[line_id]['Spend_EUR']
# Out:
# ('201300', '199200')
